# %% [markdown]
# # Modular PINN to solve the 1D Poisson Equation using d^2 x / dt^2 = sin(x) module

# %%
import numpy as np

import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.autograd as ag

from matplotlib.patches import Ellipse, Circle

# %% [markdown]
# Add SinLU Activation function for the PINN

# %%
class SinLU(nn.Module):
    def __init__(self):
        super(SinLU,self).__init__()
        self.a = nn.Parameter(torch.ones(1))
        self.b = nn.Parameter(torch.ones(1))
    def forward(self,x):
        return torch.sigmoid(x)*(x+self.a*torch.sin(self.b*x))
        #return self.a*torch.sin(self.b*x) # sin activation function

# %% [markdown]
# Build a larger architecture from to two models

# %%
class MyHugeModel(nn.Module):
    def __init__(self, model1, model2, model3):
        super(MyHugeModel, self).__init__()
        self.model1 = model1
        self.model2 = model2
        self.model3 = model3
        #self.model4 = model4
        
    def forward(self, x):
        x = self.model1(x) + self.model2(x)  + self.model3(x) #+ self.model4(x)
        #x = self.model1(x) # here we are composing
        #x = self.model2(x)
        return x

# %% [markdown]
# BIMT NN Class to perform the brain-inspired neural network

# %%
class BioLinear(nn.Module):
    # BioLinear is just Linear, but each neuron comes with coordinates.
    def __init__(self, in_dim, out_dim, in_fold=1, out_fold=1):
        super(BioLinear, self).__init__()
        self.in_dim = in_dim
        self.out_dim = out_dim
        self.linear = nn.Linear(in_dim, out_dim)
        self.in_fold = in_fold # in_fold is the number of folds applied to input vectors. It only affects coordinates, not computations.
        self.out_fold = out_fold # out_fold is the number of folds applied to output vectors. It only affects coordinates, not computations.
        assert in_dim % in_fold == 0
        assert out_dim % out_fold == 0
        #compute in_cor, shape: (in_dim)
        in_dim_fold = int(in_dim/in_fold)
        out_dim_fold = int(out_dim/out_fold)
        self.in_coordinates = torch.tensor(list(np.linspace(1/(2*in_dim_fold), 1-1/(2*in_dim_fold), num=in_dim_fold))*in_fold, dtype=torch.float) # place input neurons in 1D Euclidean space
        self.out_coordinates = torch.tensor(list(np.linspace(1/(2*out_dim_fold), 1-1/(2*out_dim_fold), num=out_dim_fold))*out_fold, dtype=torch.float) # place output neurons in 1D Euclidean space
        self.input = None
        self.output = None
        
    def forward(self, x):
        self.input = x.clone()
        self.output = self.linear(x).clone()
        return self.output

class BioMLP(nn.Module):
    # BioMLP is just MLP, but each neuron comes with coordinates.
    def __init__(self, in_dim=2, out_dim=2, w=2, depth=2, shp=None, token_embedding=False, embedding_size=None):
        super(BioMLP, self).__init__()
        if shp == None:
            shp = [in_dim] + [w]*(depth-1) + [out_dim]
            self.in_dim = in_dim
            self.out_dim = out_dim
            self.depth = depth
                 
        else:
            self.in_dim = shp[0]
            self.out_dim = shp[-1]
            self.depth = len(shp) - 1

        linear_list = []
        for i in range(self.depth):
            if i == 0:
                linear_list.append(BioLinear(shp[i], shp[i+1], in_fold=1))
                
            else:
                linear_list.append(BioLinear(shp[i], shp[i+1]))
        self.linears = nn.ModuleList(linear_list)
        
        
        if token_embedding == True:
            # embedding size: number of tokens * embedding dimension
            self.embedding = torch.nn.Parameter(torch.normal(0,1,size=embedding_size))
        
        self.shp = shp
        # parameters for the bio-inspired trick
        self.l0 = 0.1 # distance between two nearby layers
        self.in_perm = torch.nn.Parameter(torch.tensor(np.arange(int(self.in_dim/self.linears[0].in_fold)), dtype=torch.float))
        self.out_perm = torch.nn.Parameter(torch.tensor(np.arange(int(self.out_dim/self.linears[-1].out_fold)), dtype=torch.float))
        self.top_k = 5 # the number of important neurons (used in Swaps)
        self.token_embedding = token_embedding
        self.n_parameters = sum(p.numel() for p in self.parameters())
        self.original_params = None

    def forward(self, x):
        shp = x.shape
        in_fold = self.linears[0].in_fold
        x = x.reshape(shp[0], in_fold, int(shp[1]/in_fold))
        x = x[:,:,self.in_perm.long()]
        x = x.reshape(shp[0], shp[1])
        
        #HERE we define the activation. Original SiLU
        #f = torch.nn.SiLU() #swish
        #f = torch.nn.Tanh() # Tanh performs largely better for basic case / but less sparse representaion
        f = SinLU()
        
        for i in range(self.depth-1):
            x = f(self.linears[i](x))
        x = self.linears[-1](x)
        
        out_perm_inv = torch.zeros(self.out_dim, dtype=torch.long)
        out_perm_inv[self.out_perm.long()] = torch.arange(self.out_dim)
        x = x[:,out_perm_inv]
        #x = x[:,self.out_perm]
        
        return x
    
    def get_linear_layers(self):
        return self.linears
    
    def get_cc(self, weight_factor=1.0, bias_penalize=True, no_penalize_last=False):
        # compute connection cost
        # bias_penalize = True penalizes biases, otherwise doesn't penalize biases
        # no_penalize_last = True means do not penalize last linear layer, False means penalize last layer.
        cc = 0
        num_linear = len(self.linears)
        for i in range(num_linear):
            if i == num_linear - 1 and no_penalize_last:
                weight_factor = 0.
            biolinear = self.linears[i]
            dist = torch.abs(biolinear.out_coordinates.unsqueeze(dim=1) - biolinear.in_coordinates.unsqueeze(dim=0))
            cc += torch.sum(torch.abs(biolinear.linear.weight)*(weight_factor*dist+self.l0))
            if bias_penalize == True:
                cc += torch.sum(torch.abs(biolinear.linear.bias)*(self.l0))
        if self.token_embedding:
            cc += torch.sum(torch.abs(self.embedding)*(self.l0))
            #pass
        return cc
    
    def swap_weight(self, weights, j, k, swap_type="out"):
        # Given a weight matrix, swap the j^th and k^th neuron in inputs/outputs when swap_type = "in"/"out"
        with torch.no_grad():  
            if swap_type == "in":
                temp = weights[:,j].clone()
                weights[:,j] = weights[:,k].clone()
                weights[:,k] = temp
            elif swap_type == "out":
                temp = weights[j].clone()
                weights[j] = weights[k].clone()
                weights[k] = temp
            else:
                raise Exception("Swap type {} is not recognized!".format(swap_type))
            
    def swap_bias(self, biases, j, k):
        # Given a bias vector, swap the j^th and k^th neuron.
        with torch.no_grad():  
            temp = biases[j].clone()
            biases[j] = biases[k].clone()
            biases[k] = temp
    
    def swap(self, i, j, k):
        # in the ith layer (of neurons), swap the jth and the kth neuron. 
        # Note: n layers of weights means n+1 layers of neurons.
        linears = self.get_linear_layers()
        num_linear = len(linears)
        if i == 0:
            # input layer, only has outgoing weights; update in_perm
            weights = linears[i].linear.weight
            infold = linears[i].in_fold
            fold_dim = int(weights.shape[1]/infold)
            for l in range(infold):
                self.swap_weight(weights, j+fold_dim*l, k+fold_dim*l, swap_type="in")
            # change input_perm
            self.swap_bias(self.in_perm, j, k)
        elif i == num_linear:
            # output layer, only has incoming weights and biases; update out_perm
            weights = linears[i-1].linear.weight
            biases = linears[i-1].linear.bias
            self.swap_weight(weights, j, k, swap_type="out")
            self.swap_bias(biases, j, k)
            # change output_perm
            self.swap_bias(self.out_perm, j, k)
        else:
            # middle layer : incoming weights, outgoing weights, and biases
            weights_in = linears[i-1].linear.weight
            weights_out = linears[i].linear.weight
            biases = linears[i-1].linear.bias
            self.swap_weight(weights_in, j, k, swap_type="out")
            self.swap_weight(weights_out, j, k, swap_type="in")
            self.swap_bias(biases, j, k)

    def get_top_id(self, i, top_k=20):
        # in the ith layer (of neurons), get the top k important neurons (have large weight connections with other neurons)
        linears = self.get_linear_layers()
        num_linear = len(linears)
        if i == 0:
            # input layer
            weights = linears[i].linear.weight
            score = torch.sum(torch.abs(weights), dim=0)
            in_fold = linears[0].in_fold
            #print(score.shape)
            score = torch.sum(score.reshape(in_fold, int(score.shape[0]/in_fold)), dim=0)
        elif i == num_linear:
            # output layer
            weights = linears[i-1].linear.weight
            score = torch.sum(torch.abs(weights), dim=1)
        else:
            weights_in = linears[i-1].linear.weight
            weights_out = linears[i].linear.weight
            score = torch.sum(torch.abs(weights_out), dim=0) + torch.sum(torch.abs(weights_in), dim=1)
        #print(score.shape)
        top_index = torch.flip(torch.argsort(score),[0])[:top_k]
        return top_index
    
    def relocate_ij(self, i, j):
        # In the ith layer (of neurons), relocate the jth neuron
        linears = self.get_linear_layers()
        num_linear = len(linears)
        if i < num_linear:
            num_neuron = int(linears[i].linear.weight.shape[1]/linears[i].in_fold)
        else:
            num_neuron = linears[i-1].linear.weight.shape[0]
        ccs = []
        for k in range(num_neuron):
            self.swap(i,j,k)
            ccs.append(self.get_cc())
            self.swap(i,j,k)
        k = torch.argmin(torch.stack(ccs))
        self.swap(i,j,k)
            
    def relocate_i(self, i):
        # Relocate neurons in the ith layer
        top_id = self.get_top_id(i, top_k=self.top_k)
        for j in top_id:
            self.relocate_ij(i,j)
            
    def relocate(self):
        # Relocate neurons in the whole model
        linears = self.get_linear_layers()
        num_linear = len(linears)
        for i in range(num_linear+1):
            self.relocate_i(i)
            
    def plot(self):
        fig, ax = plt.subplots(figsize=(5,5))
        #ax = plt.gca()
        shp = self.shp
        s = 1/(2*max(shp))
        for j in range(len(shp)):
            N = shp[j]
            if j == 0:
                in_fold = self.linears[j].in_fold
                N = int(N/in_fold)
            for i in range(N):
                if j == 0:
                    for fold in range(in_fold):
                        circle = Ellipse((1/(2*N)+i/N, 0.1*j+0.02*fold-0.01), s, s/10*((len(shp)-1)+0.4), color='black')
                        ax.add_patch(circle)
                else:
                    for fold in range(in_fold):
                        circle = Ellipse((1/(2*N)+i/N, 0.1*j), s, s/10*((len(shp)-1)+0.4), color='black')
                        ax.add_patch(circle)


        plt.ylim(-0.02,0.1*(len(shp)-1)+0.02)
        plt.xlim(-0.02,1.02)

        linears = self.linears
        for ii in range(len(linears)):
            biolinear = linears[ii]
            p = biolinear.linear.weight
            p_shp = p.shape
            p = p/torch.abs(p).max()
            in_fold = biolinear.in_fold
            fold_num = int(p_shp[1]/in_fold)
            for i in range(p_shp[0]):
                if ii == 0:
                    for fold in range(in_fold):
                        for j in range(fold_num): # switch red and blue wrt original implementation
                            plt.plot([1/(2*p_shp[0])+i/p_shp[0], 1/(2*fold_num)+j/fold_num], [0.1*(ii+1),0.1*ii+0.02*fold-0.01], lw=1*np.abs(p[i,j].detach().numpy()), color="red" if p[i,j]>0 else "blue")
                else:
                    for j in range(fold_num): # switch red and blue wrt original implementation
                        plt.plot([1/(2*p_shp[0])+i/p_shp[0], 1/(2*fold_num)+j/fold_num], [0.1*(ii+1),0.1*ii], lw=0.5*np.abs(p[i,j].detach().numpy()), color="red" if p[i,j]>0 else "blue")
                    
        ax.axis('off')
        
        
    def thresholding(self, threshold, checkpoint = True):
        # snap too small weights (smaller than threshold) to zero. Useful for pruning.
        num = 0
        if checkpoint:
            self.original_params = [param.clone() for param in self.parameters()]
        with torch.no_grad():
            for param in self.parameters():
                num += torch.sum(torch.abs(param)>threshold)
                param.data = param*(torch.abs(param)>threshold)
        return num
                
    def intervening(self, i, pos, value, ptype="weight", checkpoint = True):
        if checkpoint:
            self.original_params = [param.clone() for param in self.parameters()]
        with torch.no_grad():
            if ptype == "weight":
                self.linears[i].linear.weight[pos] = value
            elif ptype == "bias":
                self.linears[i].linear.bias[pos] = value
                
    def revert(self):
        with torch.no_grad():
            for param, original_param in zip(self.parameters(), self.original_params):
                param.data.copy_(original_param.data)

# %% [markdown]
# Set the random number seed for reproducibility

# %%
## CODE STARTS ##
# set random number for reproducibility
seed = 47
np.random.seed(seed)
torch.manual_seed(seed)

# %%
# Added typical PINN initialization
def init_weights(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_normal_(m.weight)
        m.bias.data.fill_(0.01)

# %% [markdown]
# Define the source term $s(x)$ of the 1D Poisson equation: $d^2 x (t) / dt^2 = s(t)$

# %%
def source_term(t: torch.Tensor) -> torch.Tensor:
    A: float = 1.0
    #return torch.sin(t)   - 4*torch.sin(2.0*t) #+ 9*torch.sin(3.0*t)  # #t*(1-t)
    return torch.sin(t) + 4*torch.sin(2.0*t) + 9*torch.sin(3.0*t)  + 16*torch.sin(4.0*t)   # #t*(1-t)

# %% [markdown]
# Define the size of the initial PINN architecture. Initially it is a fully connected network.

# %%
# Input and output neurons
d_in = 1
d_out = 1
# batch
dataset_size = 1000 # 5000
dataset_size_BC = 50 #100
# Steps
steps = 100000 # 50001

# Network architecture: Initially Fully-Connected
width = 3
depth = 3 # 3
shp1 = [d_in, width, d_out]   #20,20
width = 3
depth = 3 # 3
shp2 = [d_in, width, d_out]   #20,20
width = 3
depth = 3 # 3
shp3 = [d_in, width, d_out]   #20,20
#width = 3
#depth = 3 # 3
#shp4 = [d_in, width, d_out]   #20,20

# %% [markdown]
# Construct the 2 BIMT networks and initialize superclass and select the *optimizer* and learning rate

# %%
# construct the initial MLP1
model1 = BioMLP(shp=shp1)
model1.apply(init_weights)
# construct the initial MLP2
model2 = BioMLP(shp=shp2)
model2.apply(init_weights)
# construct the initial MLP3
model3 = BioMLP(shp=shp3)
model3.apply(init_weights)
# construct the initial MLP4
#model4 = BioMLP(shp=shp4)
#model4.apply(init_weights)

model = MyHugeModel(model1, model2, model3)

# set the optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=0.002, weight_decay=0.0)

# %% [markdown]
# Select the kind of training - Locality, Swap and L1

# %%
# train_type = 1; no L1
# train_type = 2; L1
# train_type = 3: L1 + Local
# train_type = 4: L1 + Swap
# train_type = 5: L1 + Local + Swap
train_type = 1 #5

# %% [markdown]
# Create the input and test data sets

# %%
# create the training data. Matrix dataset_size x 1
# Data between 0 and 2pi
inputs = np.random.rand(dataset_size,d_in)*2.0*np.pi
inputsBC0 = np.zeros((dataset_size_BC,d_in))
inputsBC1 = 2.0*np.pi*np.ones((dataset_size_BC,d_in)) # right BC is on 2pi
# create pytorch tensors
inputs = torch.tensor(inputs, dtype=torch.float, requires_grad=True)
inputsBC0 = torch.tensor(inputsBC0, dtype=torch.float, requires_grad=True)
inputsBC1 = torch.tensor(inputsBC1, dtype=torch.float, requires_grad=True)


# create the test data: only 200 datapoints
# Data between 0 and 2 pi
inputs_test = np.random.rand(100,d_in)*2.0*np.pi
inputs_test = torch.tensor(inputs_test, dtype=torch.float, requires_grad=True)

# %% [markdown]
# Analytical Solution **Note it needs to change if source change**

# %%
# Analytical solution
Analytical_sol = -np.sin(inputs_test.detach().numpy()) -np.sin(2.0*inputs_test.detach().numpy()) -np.sin(3.0*inputs_test.detach().numpy()) -np.sin(4.0*inputs_test.detach().numpy())

# %% [markdown]
# Logs for performing output

# %%
# Frequency for printing losses
log = 100
# Frequency for plotting architecture
plot_log = 25000

# %% [markdown]
# Select the penalization coefficient (lambda) and frequency for swapping and weighting factor

# %%
# lambda
lamb = 0 if train_type==1 else 0.001
# swap
swap_log = 200 if train_type >= 4 else float('inf') # 200
# weight factor
weight_factor = 1. if train_type == 3 or train_type == 5 else 0.

# %% [markdown]
# Create arrays for storing history of the loss function

# %%
# arrays for storing history of loss functions
hist_train_loss = []
hist_tot_loss = []
hist_reg = []
hist_test_error = []

# %% [markdown]
# Plot the initial PINN architecture. It is fully connected.

# %%
model1.plot()
plt.show()

# %% [markdown]
# ### BIMT PINN Training
#
# This a foor loop with *steps* epochs
# It plots the PINN architecture at different steps

# %%
for step in range(steps):
    
    # Lambda changes in three different phases: lamda = 0.001 --> 0.01 --> 0.1
    if step == int(steps/4): 
        lamb *= 10 # change lambda
        print("Lambda Change at step: ", step)
    
    if step == int(3*steps/4):
        lamb *= 0.1 # change lambda
        print("Lambda Change at step: ", step)
    
    optimizer.zero_grad()
    
    ####################
    # Calculate the loss
    ####################
    
    # 1. Inner domain points
    pred  = model(inputs)
    # first derivative
    du = ag.grad(pred, inputs, torch.ones_like(pred), create_graph=True)[0]
    # second derivative
    d2u = ag.grad(du, inputs, torch.ones_like(du), create_graph=True)[0]
    res = d2u - source_term(inputs)
    
    # 2. Left BC
    pred  = model(inputsBC0)
    res0 = pred

    # 3. Right BC
    pred  = model(inputsBC1)
    res1 = pred

    # the loss function has three parts: collocation points + BC0 + BC1
    loss = torch.mean(res**2) + torch.mean(res0**2) + torch.mean(res1**2)
    
    #calculate test
    pred_test = model(inputs_test)
    test_error = np.mean((pred_test.detach().numpy() - Analytical_sol)**2)


    # history
    hist_train_loss.append(loss.detach().numpy())
    hist_test_error.append(test_error )
    
    #reg = model.get_cc(bias_penalize=True)
    total_loss = loss 
    
    # record total loss and regularization
    hist_tot_loss.append(total_loss.detach().numpy())

    total_loss.backward()
    optimizer.step()
    
    if step % log == 0:
        print("step = %d | total loss: %.2e | train loss: %.2e |  test error: %.2e "%(step, total_loss.detach().numpy(), loss.detach().numpy(), test_error))
# Out:
# step = 0 | total loss: 2.55e+02 | train loss: 2.55e+02 |  test error: 1.48e+01
# step = 100 | total loss: 1.83e+02 | train loss: 1.83e+02 |  test error: 9.57e-01
# step = 200 | total loss: 1.79e+02 | train loss: 1.79e+02 |  test error: 1.37e+00
# step = 300 | total loss: 1.77e+02 | train loss: 1.77e+02 |  test error: 1.43e+00
# step = 400 | total loss: 1.70e+02 | train loss: 1.70e+02 |  test error: 1.69e+00
# step = 500 | total loss: 1.60e+02 | train loss: 1.60e+02 |  test error: 2.63e+00
# step = 600 | total loss: 1.45e+02 | train loss: 1.45e+02 |  test error: 4.33e+00
# step = 700 | total loss: 1.32e+02 | train loss: 1.32e+02 |  test error: 6.04e+00
# step = 800 | total loss: 1.22e+02 | train loss: 1.22e+02 |  test error: 7.92e+00
# step = 900 | total loss: 1.16e+02 | train loss: 1.16e+02 |  test error: 9.59e+00
# step = 1000 | total loss: 1.14e+02 | train loss: 1.14e+02 |  test error: 1.12e+01
# step = 1100 | total loss: 1.13e+02 | train loss: 1.13e+02 |  test error: 1.25e+01
# step = 1200 | total loss: 1.12e+02 | train loss: 1.12e+02 |  test error: 1.36e+01
# step = 1300 | total loss: 1.11e+02 | train loss: 1.11e+02 |  test error: 1.48e+01
# step = 1400 | total loss: 1.10e+02 | train loss: 1.10e+02 |  test error: 1.62e+01
# step = 1500 | total loss: 1.09e+02 | train loss: 1.09e+02 |  test error: 1.75e+01
# step = 1600 | total loss: 1.08e+02 | train loss: 1.08e+02 |  test error: 1.85e+01
# step = 1700 | total loss: 1.07e+02 | train loss: 1.07e+02 |  test error: 1.92e+01
# step = 1800 | total loss: 1.07e+02 | train loss: 1.07e+02 |  test error: 1.98e+01
# step = 1900 | total loss: 1.06e+02 | train loss: 1.06e+02 |  test error: 2.05e+01
# step = 2000 | total loss: 1.06e+02 | train loss: 1.06e+02 |  test error: 2.13e+01
# step = 2100 | total loss: 1.06e+02 | train loss: 1.06e+02 |  test error: 2.23e+01
# step = 2200 | total loss: 1.05e+02 | train loss: 1.05e+02 |  test error: 2.33e+01
# step = 2300 | total loss: 1.05e+02 | train loss: 1.05e+02 |  test error: 2.44e+01
# step = 2400 | total loss: 1.05e+02 | train loss: 1.05e+02 |  test error: 2.53e+01
# step = 2500 | total loss: 1.04e+02 | train loss: 1.04e+02 |  test error: 2.63e+01
# step = 2600 | total loss: 1.04e+02 | train loss: 1.04e+02 |  test error: 2.71e+01
# step = 2700 | total loss: 1.04e+02 | train loss: 1.04e+02 |  test error: 2.80e+01
# step = 2800 | total loss: 1.04e+02 | train loss: 1.04e+02 |  test error: 2.88e+01
# step = 2900 | total loss: 1.04e+02 | train loss: 1.04e+02 |  test error: 2.96e+01
# step = 3000 | total loss: 1.03e+02 | train loss: 1.03e+02 |  test error: 3.04e+01
# step = 3100 | total loss: 1.03e+02 | train loss: 1.03e+02 |  test error: 3.11e+01
# step = 3200 | total loss: 1.03e+02 | train loss: 1.03e+02 |  test error: 3.18e+01
# step = 3300 | total loss: 1.03e+02 | train loss: 1.03e+02 |  test error: 3.25e+01
# step = 3400 | total loss: 1.02e+02 | train loss: 1.02e+02 |  test error: 3.34e+01
# step = 3500 | total loss: 9.98e+01 | train loss: 9.98e+01 |  test error: 3.63e+01
# step = 3600 | total loss: 9.33e+01 | train loss: 9.33e+01 |  test error: 4.28e+01
# step = 3700 | total loss: 8.53e+01 | train loss: 8.53e+01 |  test error: 4.91e+01
# step = 3800 | total loss: 7.96e+01 | train loss: 7.96e+01 |  test error: 5.46e+01
# step = 3900 | total loss: 7.68e+01 | train loss: 7.68e+01 |  test error: 5.83e+01
# step = 4000 | total loss: 7.57e+01 | train loss: 7.57e+01 |  test error: 5.99e+01
# step = 4100 | total loss: 7.52e+01 | train loss: 7.52e+01 |  test error: 6.00e+01
# step = 4200 | total loss: 7.48e+01 | train loss: 7.48e+01 |  test error: 5.93e+01
# step = 4300 | total loss: 7.46e+01 | train loss: 7.46e+01 |  test error: 5.82e+01
# step = 4400 | total loss: 7.43e+01 | train loss: 7.43e+01 |  test error: 5.68e+01
# step = 4500 | total loss: 7.40e+01 | train loss: 7.40e+01 |  test error: 5.48e+01
# step = 4600 | total loss: 7.38e+01 | train loss: 7.38e+01 |  test error: 5.20e+01
# step = 4700 | total loss: 7.35e+01 | train loss: 7.35e+01 |  test error: 4.88e+01
# step = 4800 | total loss: 7.33e+01 | train loss: 7.33e+01 |  test error: 4.53e+01
# step = 4900 | total loss: 7.30e+01 | train loss: 7.30e+01 |  test error: 4.15e+01
# step = 5000 | total loss: 7.27e+01 | train loss: 7.27e+01 |  test error: 3.72e+01
# step = 5100 | total loss: 7.24e+01 | train loss: 7.24e+01 |  test error: 3.32e+01
# step = 5200 | total loss: 7.22e+01 | train loss: 7.22e+01 |  test error: 3.03e+01
# step = 5300 | total loss: 7.21e+01 | train loss: 7.21e+01 |  test error: 2.90e+01
# step = 5400 | total loss: 7.19e+01 | train loss: 7.19e+01 |  test error: 2.86e+01
# step = 5500 | total loss: 7.18e+01 | train loss: 7.18e+01 |  test error: 2.85e+01
# step = 5600 | total loss: 7.17e+01 | train loss: 7.17e+01 |  test error: 2.85e+01
# step = 5700 | total loss: 7.16e+01 | train loss: 7.16e+01 |  test error: 2.85e+01
# step = 5800 | total loss: 7.15e+01 | train loss: 7.15e+01 |  test error: 2.85e+01
# step = 5900 | total loss: 7.14e+01 | train loss: 7.14e+01 |  test error: 2.83e+01
# step = 6000 | total loss: 7.13e+01 | train loss: 7.13e+01 |  test error: 2.82e+01
# step = 6100 | total loss: 7.12e+01 | train loss: 7.12e+01 |  test error: 2.81e+01
# step = 6200 | total loss: 7.11e+01 | train loss: 7.11e+01 |  test error: 2.78e+01
# step = 6300 | total loss: 7.10e+01 | train loss: 7.10e+01 |  test error: 2.76e+01
# step = 6400 | total loss: 7.09e+01 | train loss: 7.09e+01 |  test error: 2.74e+01
# step = 6500 | total loss: 7.08e+01 | train loss: 7.08e+01 |  test error: 2.71e+01
# step = 6600 | total loss: 7.07e+01 | train loss: 7.07e+01 |  test error: 2.68e+01
# step = 6700 | total loss: 7.07e+01 | train loss: 7.07e+01 |  test error: 2.65e+01
# step = 6800 | total loss: 7.06e+01 | train loss: 7.06e+01 |  test error: 2.62e+01
# step = 6900 | total loss: 7.05e+01 | train loss: 7.05e+01 |  test error: 2.58e+01
# step = 7000 | total loss: 7.04e+01 | train loss: 7.04e+01 |  test error: 2.55e+01
# step = 7100 | total loss: 7.03e+01 | train loss: 7.03e+01 |  test error: 2.51e+01
# step = 7200 | total loss: 7.03e+01 | train loss: 7.03e+01 |  test error: 2.47e+01
# step = 7300 | total loss: 7.02e+01 | train loss: 7.02e+01 |  test error: 2.44e+01
# step = 7400 | total loss: 7.01e+01 | train loss: 7.01e+01 |  test error: 2.38e+01
# step = 7500 | total loss: 7.00e+01 | train loss: 7.00e+01 |  test error: 2.34e+01
# step = 7600 | total loss: 6.99e+01 | train loss: 6.99e+01 |  test error: 2.29e+01
# step = 7700 | total loss: 6.99e+01 | train loss: 6.99e+01 |  test error: 2.24e+01
# step = 7800 | total loss: 6.98e+01 | train loss: 6.98e+01 |  test error: 2.19e+01
# step = 7900 | total loss: 6.97e+01 | train loss: 6.97e+01 |  test error: 2.12e+01
# step = 8000 | total loss: 6.95e+01 | train loss: 6.95e+01 |  test error: 1.68e+01
# step = 8100 | total loss: 6.89e+01 | train loss: 6.89e+01 |  test error: 1.14e+01
# step = 8200 | total loss: 6.87e+01 | train loss: 6.87e+01 |  test error: 1.05e+01
# step = 8300 | total loss: 6.85e+01 | train loss: 6.85e+01 |  test error: 9.62e+00
# step = 8400 | total loss: 6.84e+01 | train loss: 6.84e+01 |  test error: 8.85e+00
# step = 8500 | total loss: 6.82e+01 | train loss: 6.82e+01 |  test error: 8.23e+00
# step = 8600 | total loss: 6.81e+01 | train loss: 6.81e+01 |  test error: 7.67e+00
# step = 8700 | total loss: 6.80e+01 | train loss: 6.80e+01 |  test error: 7.11e+00
# step = 8800 | total loss: 6.79e+01 | train loss: 6.79e+01 |  test error: 6.72e+00
# step = 8900 | total loss: 6.78e+01 | train loss: 6.78e+01 |  test error: 6.30e+00
# step = 9000 | total loss: 6.78e+01 | train loss: 6.78e+01 |  test error: 5.99e+00
# step = 9100 | total loss: 6.77e+01 | train loss: 6.77e+01 |  test error: 5.58e+00
# step = 9200 | total loss: 6.76e+01 | train loss: 6.76e+01 |  test error: 5.28e+00
# step = 9300 | total loss: 6.75e+01 | train loss: 6.75e+01 |  test error: 4.97e+00
# step = 9400 | total loss: 6.75e+01 | train loss: 6.75e+01 |  test error: 4.68e+00
# step = 9500 | total loss: 6.74e+01 | train loss: 6.74e+01 |  test error: 4.43e+00
# step = 9600 | total loss: 6.73e+01 | train loss: 6.73e+01 |  test error: 4.19e+00
# step = 9700 | total loss: 6.73e+01 | train loss: 6.73e+01 |  test error: 3.98e+00
# step = 9800 | total loss: 6.72e+01 | train loss: 6.72e+01 |  test error: 3.75e+00
# step = 9900 | total loss: 6.72e+01 | train loss: 6.72e+01 |  test error: 3.56e+00
# step = 10000 | total loss: 6.71e+01 | train loss: 6.71e+01 |  test error: 3.37e+00
# step = 10100 | total loss: 6.71e+01 | train loss: 6.71e+01 |  test error: 3.19e+00
# step = 10200 | total loss: 6.70e+01 | train loss: 6.70e+01 |  test error: 3.05e+00
# step = 10300 | total loss: 6.70e+01 | train loss: 6.70e+01 |  test error: 2.88e+00
# step = 10400 | total loss: 6.69e+01 | train loss: 6.69e+01 |  test error: 2.73e+00
# step = 10500 | total loss: 6.69e+01 | train loss: 6.69e+01 |  test error: 2.60e+00
# step = 10600 | total loss: 6.69e+01 | train loss: 6.69e+01 |  test error: 2.48e+00
# step = 10700 | total loss: 6.68e+01 | train loss: 6.68e+01 |  test error: 2.36e+00
# step = 10800 | total loss: 6.68e+01 | train loss: 6.68e+01 |  test error: 2.25e+00
# step = 10900 | total loss: 6.67e+01 | train loss: 6.67e+01 |  test error: 2.14e+00
# step = 11000 | total loss: 6.67e+01 | train loss: 6.67e+01 |  test error: 2.06e+00
# step = 11100 | total loss: 6.67e+01 | train loss: 6.67e+01 |  test error: 1.95e+00
# step = 11200 | total loss: 6.66e+01 | train loss: 6.66e+01 |  test error: 1.86e+00
# step = 11300 | total loss: 6.66e+01 | train loss: 6.66e+01 |  test error: 1.78e+00
# step = 11400 | total loss: 6.66e+01 | train loss: 6.66e+01 |  test error: 1.70e+00
# step = 11500 | total loss: 6.66e+01 | train loss: 6.66e+01 |  test error: 1.62e+00
# step = 11600 | total loss: 6.65e+01 | train loss: 6.65e+01 |  test error: 1.56e+00
# step = 11700 | total loss: 6.65e+01 | train loss: 6.65e+01 |  test error: 1.50e+00
# step = 11800 | total loss: 6.65e+01 | train loss: 6.65e+01 |  test error: 1.43e+00
# step = 11900 | total loss: 6.65e+01 | train loss: 6.65e+01 |  test error: 1.37e+00
# step = 12000 | total loss: 6.64e+01 | train loss: 6.64e+01 |  test error: 1.36e+00
# step = 12100 | total loss: 6.64e+01 | train loss: 6.64e+01 |  test error: 1.26e+00
# step = 12200 | total loss: 6.64e+01 | train loss: 6.64e+01 |  test error: 1.22e+00
# step = 12300 | total loss: 6.64e+01 | train loss: 6.64e+01 |  test error: 1.17e+00
# step = 12400 | total loss: 6.64e+01 | train loss: 6.64e+01 |  test error: 1.09e+00
# step = 12500 | total loss: 6.63e+01 | train loss: 6.63e+01 |  test error: 1.08e+00
# step = 12600 | total loss: 6.63e+01 | train loss: 6.63e+01 |  test error: 1.05e+00
# step = 12700 | total loss: 6.63e+01 | train loss: 6.63e+01 |  test error: 1.01e+00
# step = 12800 | total loss: 6.63e+01 | train loss: 6.63e+01 |  test error: 9.74e-01
# step = 12900 | total loss: 6.63e+01 | train loss: 6.63e+01 |  test error: 9.29e-01
# step = 13000 | total loss: 6.62e+01 | train loss: 6.62e+01 |  test error: 9.09e-01
# step = 13100 | total loss: 6.62e+01 | train loss: 6.62e+01 |  test error: 8.75e-01
# step = 13200 | total loss: 6.62e+01 | train loss: 6.62e+01 |  test error: 8.51e-01
# step = 13300 | total loss: 6.62e+01 | train loss: 6.62e+01 |  test error: 8.22e-01
# step = 13400 | total loss: 6.62e+01 | train loss: 6.62e+01 |  test error: 7.88e-01
# step = 13500 | total loss: 6.62e+01 | train loss: 6.62e+01 |  test error: 7.74e-01
# step = 13600 | total loss: 6.61e+01 | train loss: 6.61e+01 |  test error: 7.51e-01
# step = 13700 | total loss: 6.61e+01 | train loss: 6.61e+01 |  test error: 7.35e-01
# step = 13800 | total loss: 6.61e+01 | train loss: 6.61e+01 |  test error: 7.11e-01
# step = 13900 | total loss: 6.61e+01 | train loss: 6.61e+01 |  test error: 6.99e-01
# step = 14000 | total loss: 6.61e+01 | train loss: 6.61e+01 |  test error: 6.96e-01
# step = 14100 | total loss: 6.59e+01 | train loss: 6.59e+01 |  test error: 6.33e-01
# step = 14200 | total loss: 6.55e+01 | train loss: 6.55e+01 |  test error: 4.34e-01
# step = 14300 | total loss: 6.45e+01 | train loss: 6.45e+01 |  test error: 4.55e-01
# step = 14400 | total loss: 6.39e+01 | train loss: 6.39e+01 |  test error: 8.97e-01
# step = 14500 | total loss: 6.36e+01 | train loss: 6.36e+01 |  test error: 9.79e-01
# step = 14600 | total loss: 6.34e+01 | train loss: 6.34e+01 |  test error: 9.90e-01
# step = 14700 | total loss: 6.32e+01 | train loss: 6.32e+01 |  test error: 9.32e-01
# step = 14800 | total loss: 6.30e+01 | train loss: 6.30e+01 |  test error: 9.19e-01
# step = 14900 | total loss: 6.18e+01 | train loss: 6.18e+01 |  test error: 3.03e-01
# step = 15000 | total loss: 5.86e+01 | train loss: 5.86e+01 |  test error: 2.45e-01
# step = 15100 | total loss: 5.17e+01 | train loss: 5.17e+01 |  test error: 2.40e-01
# step = 15200 | total loss: 4.19e+01 | train loss: 4.19e+01 |  test error: 7.09e-01
# step = 15300 | total loss: 3.17e+01 | train loss: 3.17e+01 |  test error: 2.90e+00
# step = 15400 | total loss: 2.28e+01 | train loss: 2.28e+01 |  test error: 2.67e-01
# step = 15500 | total loss: 1.65e+01 | train loss: 1.65e+01 |  test error: 6.81e-02
# step = 15600 | total loss: 1.25e+01 | train loss: 1.25e+01 |  test error: 3.60e-02
# step = 15700 | total loss: 9.99e+00 | train loss: 9.99e+00 |  test error: 2.30e-02
# step = 15800 | total loss: 8.13e+00 | train loss: 8.13e+00 |  test error: 1.64e-02
# step = 15900 | total loss: 6.11e+00 | train loss: 6.11e+00 |  test error: 1.55e-02
# step = 16000 | total loss: 3.66e+00 | train loss: 3.66e+00 |  test error: 4.61e-02
# step = 16100 | total loss: 2.10e+00 | train loss: 2.10e+00 |  test error: 8.68e-03
# step = 16200 | total loss: 1.46e+00 | train loss: 1.46e+00 |  test error: 1.39e-02
# step = 16300 | total loss: 1.12e+00 | train loss: 1.12e+00 |  test error: 4.49e-02
# step = 16400 | total loss: 9.03e-01 | train loss: 9.03e-01 |  test error: 5.44e-02
# step = 16500 | total loss: 7.81e-01 | train loss: 7.81e-01 |  test error: 4.99e-02
# step = 16600 | total loss: 6.90e-01 | train loss: 6.90e-01 |  test error: 3.21e-02
# step = 16700 | total loss: 6.38e-01 | train loss: 6.38e-01 |  test error: 2.33e-02
# step = 16800 | total loss: 6.01e-01 | train loss: 6.01e-01 |  test error: 1.85e-02
# step = 16900 | total loss: 5.73e-01 | train loss: 5.73e-01 |  test error: 1.25e-02
# step = 17000 | total loss: 5.50e-01 | train loss: 5.50e-01 |  test error: 1.03e-02
# step = 17100 | total loss: 5.32e-01 | train loss: 5.32e-01 |  test error: 8.35e-03
# step = 17200 | total loss: 5.18e-01 | train loss: 5.18e-01 |  test error: 7.34e-03
# step = 17300 | total loss: 5.08e-01 | train loss: 5.08e-01 |  test error: 6.66e-03
# step = 17400 | total loss: 4.99e-01 | train loss: 4.99e-01 |  test error: 5.63e-03
# step = 17500 | total loss: 4.94e-01 | train loss: 4.94e-01 |  test error: 5.33e-03
# step = 17600 | total loss: 4.90e-01 | train loss: 4.90e-01 |  test error: 3.49e-03
# step = 17700 | total loss: 4.82e-01 | train loss: 4.82e-01 |  test error: 2.24e-03
# step = 17800 | total loss: 4.79e-01 | train loss: 4.79e-01 |  test error: 1.52e-03
# step = 17900 | total loss: 4.80e-01 | train loss: 4.80e-01 |  test error: 1.56e-03
# step = 18000 | total loss: 4.74e-01 | train loss: 4.74e-01 |  test error: 6.40e-04
# step = 18100 | total loss: 4.73e-01 | train loss: 4.73e-01 |  test error: 5.35e-04
# step = 18200 | total loss: 4.72e-01 | train loss: 4.72e-01 |  test error: 4.04e-04
# step = 18300 | total loss: 4.71e-01 | train loss: 4.71e-01 |  test error: 4.16e-04
# step = 18400 | total loss: 4.70e-01 | train loss: 4.70e-01 |  test error: 4.36e-04
# step = 18500 | total loss: 4.69e-01 | train loss: 4.69e-01 |  test error: 4.11e-04
# step = 18600 | total loss: 4.70e-01 | train loss: 4.70e-01 |  test error: 7.92e-04
# step = 18700 | total loss: 4.68e-01 | train loss: 4.68e-01 |  test error: 4.73e-04
# step = 18800 | total loss: 4.68e-01 | train loss: 4.68e-01 |  test error: 5.61e-04
# step = 18900 | total loss: 4.68e-01 | train loss: 4.68e-01 |  test error: 4.48e-04
# step = 19000 | total loss: 4.67e-01 | train loss: 4.67e-01 |  test error: 5.71e-04
# step = 19100 | total loss: 4.67e-01 | train loss: 4.67e-01 |  test error: 6.97e-04
# step = 19200 | total loss: 4.66e-01 | train loss: 4.66e-01 |  test error: 5.93e-04
# step = 19300 | total loss: 4.66e-01 | train loss: 4.66e-01 |  test error: 6.37e-04
# step = 19400 | total loss: 4.66e-01 | train loss: 4.66e-01 |  test error: 8.22e-04
# step = 19500 | total loss: 4.65e-01 | train loss: 4.65e-01 |  test error: 7.14e-04
# step = 19600 | total loss: 4.65e-01 | train loss: 4.65e-01 |  test error: 7.71e-04
# step = 19700 | total loss: 4.64e-01 | train loss: 4.64e-01 |  test error: 8.42e-04
# step = 19800 | total loss: 4.77e-01 | train loss: 4.77e-01 |  test error: 8.16e-04
# step = 19900 | total loss: 4.64e-01 | train loss: 4.64e-01 |  test error: 8.99e-04
# step = 20000 | total loss: 4.66e-01 | train loss: 4.66e-01 |  test error: 7.55e-04
# step = 20100 | total loss: 4.63e-01 | train loss: 4.63e-01 |  test error: 9.56e-04
# step = 20200 | total loss: 4.63e-01 | train loss: 4.63e-01 |  test error: 1.04e-03
# step = 20300 | total loss: 4.62e-01 | train loss: 4.62e-01 |  test error: 8.95e-04
# step = 20400 | total loss: 4.63e-01 | train loss: 4.63e-01 |  test error: 1.26e-03
# step = 20500 | total loss: 4.62e-01 | train loss: 4.62e-01 |  test error: 1.07e-03
# step = 20600 | total loss: 4.61e-01 | train loss: 4.61e-01 |  test error: 1.06e-03
# step = 20700 | total loss: 4.75e-01 | train loss: 4.75e-01 |  test error: 1.64e-03
# step = 20800 | total loss: 4.61e-01 | train loss: 4.61e-01 |  test error: 1.37e-03
# step = 20900 | total loss: 4.60e-01 | train loss: 4.60e-01 |  test error: 1.14e-03
# step = 21000 | total loss: 4.60e-01 | train loss: 4.60e-01 |  test error: 1.16e-03
# step = 21100 | total loss: 4.60e-01 | train loss: 4.60e-01 |  test error: 9.58e-04
# step = 21200 | total loss: 4.60e-01 | train loss: 4.60e-01 |  test error: 1.11e-03
# step = 21300 | total loss: 4.66e-01 | train loss: 4.66e-01 |  test error: 1.81e-03
# step = 21400 | total loss: 4.58e-01 | train loss: 4.58e-01 |  test error: 1.31e-03
# step = 21500 | total loss: 4.58e-01 | train loss: 4.58e-01 |  test error: 1.17e-03
# step = 21600 | total loss: 4.58e-01 | train loss: 4.58e-01 |  test error: 1.29e-03
# step = 21700 | total loss: 4.57e-01 | train loss: 4.57e-01 |  test error: 1.25e-03
# step = 21800 | total loss: 4.58e-01 | train loss: 4.58e-01 |  test error: 9.59e-04
# step = 21900 | total loss: 4.56e-01 | train loss: 4.56e-01 |  test error: 1.27e-03
# step = 22000 | total loss: 4.56e-01 | train loss: 4.56e-01 |  test error: 1.37e-03
# step = 22100 | total loss: 4.56e-01 | train loss: 4.56e-01 |  test error: 1.26e-03
# step = 22200 | total loss: 4.55e-01 | train loss: 4.55e-01 |  test error: 1.41e-03
# step = 22300 | total loss: 4.55e-01 | train loss: 4.55e-01 |  test error: 1.41e-03
# step = 22400 | total loss: 4.58e-01 | train loss: 4.58e-01 |  test error: 3.30e-03
# step = 22500 | total loss: 4.55e-01 | train loss: 4.55e-01 |  test error: 1.49e-03
# step = 22600 | total loss: 4.54e-01 | train loss: 4.54e-01 |  test error: 1.44e-03
# step = 22700 | total loss: 4.53e-01 | train loss: 4.53e-01 |  test error: 1.46e-03
# step = 22800 | total loss: 4.55e-01 | train loss: 4.55e-01 |  test error: 9.04e-04
# step = 22900 | total loss: 4.53e-01 | train loss: 4.53e-01 |  test error: 1.49e-03
# step = 23000 | total loss: 4.52e-01 | train loss: 4.52e-01 |  test error: 1.53e-03
# step = 23100 | total loss: 4.52e-01 | train loss: 4.52e-01 |  test error: 1.16e-03
# step = 23200 | total loss: 4.51e-01 | train loss: 4.51e-01 |  test error: 1.55e-03
# step = 23300 | total loss: 4.51e-01 | train loss: 4.51e-01 |  test error: 1.34e-03
# step = 23400 | total loss: 4.51e-01 | train loss: 4.51e-01 |  test error: 9.82e-04
# step = 23500 | total loss: 4.50e-01 | train loss: 4.50e-01 |  test error: 1.47e-03
# step = 23600 | total loss: 4.50e-01 | train loss: 4.50e-01 |  test error: 1.67e-03
# step = 23700 | total loss: 4.49e-01 | train loss: 4.49e-01 |  test error: 1.60e-03
# step = 23800 | total loss: 4.49e-01 | train loss: 4.49e-01 |  test error: 1.43e-03
# step = 23900 | total loss: 4.48e-01 | train loss: 4.48e-01 |  test error: 1.65e-03
# step = 24000 | total loss: 4.48e-01 | train loss: 4.48e-01 |  test error: 1.68e-03
# step = 24100 | total loss: 4.48e-01 | train loss: 4.48e-01 |  test error: 1.71e-03
# step = 24200 | total loss: 4.47e-01 | train loss: 4.47e-01 |  test error: 1.67e-03
# step = 24300 | total loss: 4.46e-01 | train loss: 4.46e-01 |  test error: 1.65e-03
# step = 24400 | total loss: 4.46e-01 | train loss: 4.46e-01 |  test error: 1.75e-03
# step = 24500 | total loss: 4.45e-01 | train loss: 4.45e-01 |  test error: 1.74e-03
# step = 24600 | total loss: 4.45e-01 | train loss: 4.45e-01 |  test error: 1.80e-03
# step = 24700 | total loss: 4.44e-01 | train loss: 4.44e-01 |  test error: 1.77e-03
# step = 24800 | total loss: 4.44e-01 | train loss: 4.44e-01 |  test error: 1.85e-03
# step = 24900 | total loss: 4.43e-01 | train loss: 4.43e-01 |  test error: 1.73e-03
# Lambda Change at step:  25000
# step = 25000 | total loss: 4.43e-01 | train loss: 4.43e-01 |  test error: 1.82e-03
# step = 25100 | total loss: 4.42e-01 | train loss: 4.42e-01 |  test error: 1.81e-03
# step = 25200 | total loss: 4.48e-01 | train loss: 4.48e-01 |  test error: 1.94e-03
# step = 25300 | total loss: 4.41e-01 | train loss: 4.41e-01 |  test error: 1.90e-03
# step = 25400 | total loss: 4.40e-01 | train loss: 4.40e-01 |  test error: 1.97e-03
# step = 25500 | total loss: 4.40e-01 | train loss: 4.40e-01 |  test error: 1.91e-03
# step = 25600 | total loss: 4.39e-01 | train loss: 4.39e-01 |  test error: 1.98e-03
# step = 25700 | total loss: 4.41e-01 | train loss: 4.41e-01 |  test error: 2.07e-03
# step = 25800 | total loss: 4.38e-01 | train loss: 4.38e-01 |  test error: 2.03e-03
# step = 25900 | total loss: 4.37e-01 | train loss: 4.37e-01 |  test error: 2.14e-03
# step = 26000 | total loss: 4.36e-01 | train loss: 4.36e-01 |  test error: 2.07e-03
# step = 26100 | total loss: 4.36e-01 | train loss: 4.36e-01 |  test error: 2.21e-03
# step = 26200 | total loss: 4.35e-01 | train loss: 4.35e-01 |  test error: 2.14e-03
# step = 26300 | total loss: 4.66e-01 | train loss: 4.66e-01 |  test error: 2.67e-03
# step = 26400 | total loss: 4.33e-01 | train loss: 4.33e-01 |  test error: 2.21e-03
# step = 26500 | total loss: 4.33e-01 | train loss: 4.33e-01 |  test error: 2.24e-03
# step = 26600 | total loss: 4.32e-01 | train loss: 4.32e-01 |  test error: 2.29e-03
# step = 26700 | total loss: 4.34e-01 | train loss: 4.34e-01 |  test error: 2.51e-03
# step = 26800 | total loss: 4.30e-01 | train loss: 4.30e-01 |  test error: 2.40e-03
# step = 26900 | total loss: 4.29e-01 | train loss: 4.29e-01 |  test error: 2.43e-03
# step = 27000 | total loss: 4.28e-01 | train loss: 4.28e-01 |  test error: 2.45e-03
# step = 27100 | total loss: 4.27e-01 | train loss: 4.27e-01 |  test error: 2.57e-03
# step = 27200 | total loss: 4.26e-01 | train loss: 4.26e-01 |  test error: 2.62e-03
# step = 27300 | total loss: 4.25e-01 | train loss: 4.25e-01 |  test error: 2.71e-03
# step = 27400 | total loss: 4.24e-01 | train loss: 4.24e-01 |  test error: 2.76e-03
# step = 27500 | total loss: 4.23e-01 | train loss: 4.23e-01 |  test error: 2.87e-03
# step = 27600 | total loss: 4.22e-01 | train loss: 4.22e-01 |  test error: 2.92e-03
# step = 27700 | total loss: 4.21e-01 | train loss: 4.21e-01 |  test error: 3.06e-03
# step = 27800 | total loss: 4.20e-01 | train loss: 4.20e-01 |  test error: 3.20e-03
# step = 27900 | total loss: 4.19e-01 | train loss: 4.19e-01 |  test error: 3.26e-03
# step = 28000 | total loss: 4.17e-01 | train loss: 4.17e-01 |  test error: 3.45e-03
# step = 28100 | total loss: 4.16e-01 | train loss: 4.16e-01 |  test error: 3.69e-03
# step = 28200 | total loss: 4.14e-01 | train loss: 4.14e-01 |  test error: 3.85e-03
# step = 28300 | total loss: 4.12e-01 | train loss: 4.12e-01 |  test error: 4.06e-03
# step = 28400 | total loss: 4.32e-01 | train loss: 4.32e-01 |  test error: 4.52e-03
# step = 28500 | total loss: 4.09e-01 | train loss: 4.09e-01 |  test error: 4.65e-03
# step = 28600 | total loss: 4.07e-01 | train loss: 4.07e-01 |  test error: 5.07e-03
# step = 28700 | total loss: 4.06e-01 | train loss: 4.06e-01 |  test error: 5.47e-03
# step = 28800 | total loss: 4.04e-01 | train loss: 4.04e-01 |  test error: 5.96e-03
# step = 28900 | total loss: 4.02e-01 | train loss: 4.02e-01 |  test error: 6.59e-03
# step = 29000 | total loss: 4.00e-01 | train loss: 4.00e-01 |  test error: 7.17e-03
# step = 29100 | total loss: 3.98e-01 | train loss: 3.98e-01 |  test error: 7.98e-03
# step = 29200 | total loss: 3.97e-01 | train loss: 3.97e-01 |  test error: 8.88e-03
# step = 29300 | total loss: 3.94e-01 | train loss: 3.94e-01 |  test error: 9.58e-03
# step = 29400 | total loss: 3.92e-01 | train loss: 3.92e-01 |  test error: 1.04e-02
# step = 29500 | total loss: 3.90e-01 | train loss: 3.90e-01 |  test error: 1.12e-02
# step = 29600 | total loss: 3.88e-01 | train loss: 3.88e-01 |  test error: 1.19e-02
# step = 29700 | total loss: 3.86e-01 | train loss: 3.86e-01 |  test error: 1.26e-02
# step = 29800 | total loss: 3.84e-01 | train loss: 3.84e-01 |  test error: 1.32e-02
# step = 29900 | total loss: 3.89e-01 | train loss: 3.89e-01 |  test error: 1.34e-02
# step = 30000 | total loss: 3.80e-01 | train loss: 3.80e-01 |  test error: 1.42e-02
# step = 30100 | total loss: 3.79e-01 | train loss: 3.79e-01 |  test error: 1.46e-02
# step = 30200 | total loss: 3.76e-01 | train loss: 3.76e-01 |  test error: 1.51e-02
# step = 30300 | total loss: 3.78e-01 | train loss: 3.78e-01 |  test error: 1.59e-02
# step = 30400 | total loss: 3.73e-01 | train loss: 3.73e-01 |  test error: 1.58e-02
# step = 30500 | total loss: 3.72e-01 | train loss: 3.72e-01 |  test error: 1.63e-02
# step = 30600 | total loss: 3.69e-01 | train loss: 3.69e-01 |  test error: 1.65e-02
# step = 30700 | total loss: 3.67e-01 | train loss: 3.67e-01 |  test error: 1.67e-02
# step = 30800 | total loss: 3.65e-01 | train loss: 3.65e-01 |  test error: 1.70e-02
# step = 30900 | total loss: 3.63e-01 | train loss: 3.63e-01 |  test error: 1.73e-02
# step = 31000 | total loss: 3.61e-01 | train loss: 3.61e-01 |  test error: 1.75e-02
# step = 31100 | total loss: 3.59e-01 | train loss: 3.59e-01 |  test error: 1.77e-02
# step = 31200 | total loss: 3.58e-01 | train loss: 3.58e-01 |  test error: 1.80e-02
# step = 31300 | total loss: 3.56e-01 | train loss: 3.56e-01 |  test error: 1.82e-02
# step = 31400 | total loss: 3.54e-01 | train loss: 3.54e-01 |  test error: 1.84e-02
# step = 31500 | total loss: 3.52e-01 | train loss: 3.52e-01 |  test error: 1.86e-02
# step = 31600 | total loss: 3.50e-01 | train loss: 3.50e-01 |  test error: 1.88e-02
# step = 31700 | total loss: 3.48e-01 | train loss: 3.48e-01 |  test error: 1.89e-02
# step = 31800 | total loss: 3.48e-01 | train loss: 3.48e-01 |  test error: 1.92e-02
# step = 31900 | total loss: 3.45e-01 | train loss: 3.45e-01 |  test error: 1.93e-02
# step = 32000 | total loss: 3.43e-01 | train loss: 3.43e-01 |  test error: 1.95e-02
# step = 32100 | total loss: 3.59e-01 | train loss: 3.59e-01 |  test error: 2.01e-02
# step = 32200 | total loss: 3.39e-01 | train loss: 3.39e-01 |  test error: 1.98e-02
# step = 32300 | total loss: 3.38e-01 | train loss: 3.38e-01 |  test error: 1.99e-02
# step = 32400 | total loss: 3.36e-01 | train loss: 3.36e-01 |  test error: 2.00e-02
# step = 32500 | total loss: 3.34e-01 | train loss: 3.34e-01 |  test error: 2.02e-02
# step = 32600 | total loss: 3.32e-01 | train loss: 3.32e-01 |  test error: 2.03e-02
# step = 32700 | total loss: 3.31e-01 | train loss: 3.31e-01 |  test error: 2.03e-02
# step = 32800 | total loss: 3.29e-01 | train loss: 3.29e-01 |  test error: 2.05e-02
# step = 32900 | total loss: 3.27e-01 | train loss: 3.27e-01 |  test error: 2.05e-02
# step = 33000 | total loss: 3.25e-01 | train loss: 3.25e-01 |  test error: 2.07e-02
# step = 33100 | total loss: 3.24e-01 | train loss: 3.24e-01 |  test error: 2.08e-02
# step = 33200 | total loss: 3.22e-01 | train loss: 3.22e-01 |  test error: 2.08e-02
# step = 33300 | total loss: 3.20e-01 | train loss: 3.20e-01 |  test error: 2.09e-02
# step = 33400 | total loss: 3.18e-01 | train loss: 3.18e-01 |  test error: 2.09e-02
# step = 33500 | total loss: 3.17e-01 | train loss: 3.17e-01 |  test error: 2.10e-02
# step = 33600 | total loss: 3.16e-01 | train loss: 3.16e-01 |  test error: 2.12e-02
# step = 33700 | total loss: 3.13e-01 | train loss: 3.13e-01 |  test error: 2.10e-02
# step = 33800 | total loss: 3.12e-01 | train loss: 3.12e-01 |  test error: 2.10e-02
# step = 33900 | total loss: 3.10e-01 | train loss: 3.10e-01 |  test error: 2.10e-02
# step = 34000 | total loss: 3.08e-01 | train loss: 3.08e-01 |  test error: 2.10e-02
# step = 34100 | total loss: 3.07e-01 | train loss: 3.07e-01 |  test error: 2.11e-02
# step = 34200 | total loss: 3.05e-01 | train loss: 3.05e-01 |  test error: 2.09e-02
# step = 34300 | total loss: 3.04e-01 | train loss: 3.04e-01 |  test error: 2.09e-02
# step = 34400 | total loss: 3.02e-01 | train loss: 3.02e-01 |  test error: 2.08e-02
# step = 34500 | total loss: 3.01e-01 | train loss: 3.01e-01 |  test error: 2.07e-02
# step = 34600 | total loss: 2.99e-01 | train loss: 2.99e-01 |  test error: 2.06e-02
# step = 34700 | total loss: 2.98e-01 | train loss: 2.98e-01 |  test error: 2.05e-02
# step = 34800 | total loss: 2.97e-01 | train loss: 2.97e-01 |  test error: 2.04e-02
# step = 34900 | total loss: 2.95e-01 | train loss: 2.95e-01 |  test error: 2.01e-02
# step = 35000 | total loss: 2.94e-01 | train loss: 2.94e-01 |  test error: 2.01e-02
# step = 35100 | total loss: 2.96e-01 | train loss: 2.96e-01 |  test error: 2.05e-02
# step = 35200 | total loss: 2.91e-01 | train loss: 2.91e-01 |  test error: 1.99e-02
# step = 35300 | total loss: 2.90e-01 | train loss: 2.90e-01 |  test error: 1.96e-02
# step = 35400 | total loss: 2.88e-01 | train loss: 2.88e-01 |  test error: 1.95e-02
# step = 35500 | total loss: 3.06e-01 | train loss: 3.06e-01 |  test error: 2.08e-02
# step = 35600 | total loss: 2.86e-01 | train loss: 2.86e-01 |  test error: 1.91e-02
# step = 35700 | total loss: 2.85e-01 | train loss: 2.85e-01 |  test error: 1.91e-02
# step = 35800 | total loss: 2.83e-01 | train loss: 2.83e-01 |  test error: 1.87e-02
# step = 35900 | total loss: 2.82e-01 | train loss: 2.82e-01 |  test error: 1.85e-02
# step = 36000 | total loss: 2.81e-01 | train loss: 2.81e-01 |  test error: 1.82e-02
# step = 36100 | total loss: 2.80e-01 | train loss: 2.80e-01 |  test error: 1.79e-02
# step = 36200 | total loss: 2.79e-01 | train loss: 2.79e-01 |  test error: 1.76e-02
# step = 36300 | total loss: 2.78e-01 | train loss: 2.78e-01 |  test error: 1.74e-02
# step = 36400 | total loss: 2.77e-01 | train loss: 2.77e-01 |  test error: 1.73e-02
# step = 36500 | total loss: 2.75e-01 | train loss: 2.75e-01 |  test error: 1.68e-02
# step = 36600 | total loss: 2.74e-01 | train loss: 2.74e-01 |  test error: 1.65e-02
# step = 36700 | total loss: 2.73e-01 | train loss: 2.73e-01 |  test error: 1.62e-02
# step = 36800 | total loss: 2.80e-01 | train loss: 2.80e-01 |  test error: 1.35e-02
# step = 36900 | total loss: 2.71e-01 | train loss: 2.71e-01 |  test error: 1.55e-02
# step = 37000 | total loss: 2.72e-01 | train loss: 2.72e-01 |  test error: 1.67e-02
# step = 37100 | total loss: 2.68e-01 | train loss: 2.68e-01 |  test error: 1.46e-02
# step = 37200 | total loss: 2.73e-01 | train loss: 2.73e-01 |  test error: 1.18e-02
# step = 37300 | total loss: 2.66e-01 | train loss: 2.66e-01 |  test error: 1.38e-02
# step = 37400 | total loss: 2.64e-01 | train loss: 2.64e-01 |  test error: 1.32e-02
# step = 37500 | total loss: 2.63e-01 | train loss: 2.63e-01 |  test error: 1.25e-02
# step = 37600 | total loss: 2.60e-01 | train loss: 2.60e-01 |  test error: 1.25e-02
# step = 37700 | total loss: 2.58e-01 | train loss: 2.58e-01 |  test error: 1.21e-02
# step = 37800 | total loss: 2.56e-01 | train loss: 2.56e-01 |  test error: 1.22e-02
# step = 37900 | total loss: 2.53e-01 | train loss: 2.53e-01 |  test error: 1.25e-02
# step = 38000 | total loss: 2.50e-01 | train loss: 2.50e-01 |  test error: 1.26e-02
# step = 38100 | total loss: 2.48e-01 | train loss: 2.48e-01 |  test error: 1.25e-02
# step = 38200 | total loss: 2.46e-01 | train loss: 2.46e-01 |  test error: 1.24e-02
# step = 38300 | total loss: 2.43e-01 | train loss: 2.43e-01 |  test error: 1.27e-02
# step = 38400 | total loss: 2.41e-01 | train loss: 2.41e-01 |  test error: 1.21e-02
# step = 38500 | total loss: 2.39e-01 | train loss: 2.39e-01 |  test error: 1.18e-02
# step = 38600 | total loss: 2.38e-01 | train loss: 2.38e-01 |  test error: 1.13e-02
# step = 38700 | total loss: 2.35e-01 | train loss: 2.35e-01 |  test error: 1.14e-02
# step = 38800 | total loss: 2.34e-01 | train loss: 2.34e-01 |  test error: 1.05e-02
# step = 38900 | total loss: 2.31e-01 | train loss: 2.31e-01 |  test error: 1.08e-02
# step = 39000 | total loss: 2.29e-01 | train loss: 2.29e-01 |  test error: 1.02e-02
# step = 39100 | total loss: 2.32e-01 | train loss: 2.32e-01 |  test error: 9.69e-03
# step = 39200 | total loss: 2.26e-01 | train loss: 2.26e-01 |  test error: 9.36e-03
# step = 39300 | total loss: 2.25e-01 | train loss: 2.25e-01 |  test error: 9.08e-03
# step = 39400 | total loss: 2.23e-01 | train loss: 2.23e-01 |  test error: 8.63e-03
# step = 39500 | total loss: 2.22e-01 | train loss: 2.22e-01 |  test error: 9.54e-03
# step = 39600 | total loss: 2.20e-01 | train loss: 2.20e-01 |  test error: 7.83e-03
# step = 39700 | total loss: 2.19e-01 | train loss: 2.19e-01 |  test error: 6.71e-03
# step = 39800 | total loss: 2.18e-01 | train loss: 2.18e-01 |  test error: 6.98e-03
# step = 39900 | total loss: 2.16e-01 | train loss: 2.16e-01 |  test error: 6.45e-03
# step = 40000 | total loss: 2.16e-01 | train loss: 2.16e-01 |  test error: 6.49e-03
# step = 40100 | total loss: 2.14e-01 | train loss: 2.14e-01 |  test error: 6.17e-03
# step = 40200 | total loss: 2.13e-01 | train loss: 2.13e-01 |  test error: 5.81e-03
# step = 40300 | total loss: 2.20e-01 | train loss: 2.20e-01 |  test error: 6.60e-03
# step = 40400 | total loss: 2.11e-01 | train loss: 2.11e-01 |  test error: 5.27e-03
# step = 40500 | total loss: 2.26e-01 | train loss: 2.26e-01 |  test error: 5.64e-03
# step = 40600 | total loss: 2.09e-01 | train loss: 2.09e-01 |  test error: 4.80e-03
# step = 40700 | total loss: 2.08e-01 | train loss: 2.08e-01 |  test error: 4.75e-03
# step = 40800 | total loss: 2.09e-01 | train loss: 2.09e-01 |  test error: 4.54e-03
# step = 40900 | total loss: 2.06e-01 | train loss: 2.06e-01 |  test error: 4.33e-03
# step = 41000 | total loss: 2.05e-01 | train loss: 2.05e-01 |  test error: 3.85e-03
# step = 41100 | total loss: 2.04e-01 | train loss: 2.04e-01 |  test error: 4.09e-03
# step = 41200 | total loss: 2.03e-01 | train loss: 2.03e-01 |  test error: 3.94e-03
# step = 41300 | total loss: 2.05e-01 | train loss: 2.05e-01 |  test error: 4.31e-03
# step = 41400 | total loss: 2.01e-01 | train loss: 2.01e-01 |  test error: 3.81e-03
# step = 41500 | total loss: 2.00e-01 | train loss: 2.00e-01 |  test error: 3.78e-03
# step = 41600 | total loss: 1.99e-01 | train loss: 1.99e-01 |  test error: 3.41e-03
# step = 41700 | total loss: 1.98e-01 | train loss: 1.98e-01 |  test error: 3.46e-03
# step = 41800 | total loss: 1.98e-01 | train loss: 1.98e-01 |  test error: 3.47e-03
# step = 41900 | total loss: 1.96e-01 | train loss: 1.96e-01 |  test error: 3.32e-03
# step = 42000 | total loss: 1.95e-01 | train loss: 1.95e-01 |  test error: 3.20e-03
# step = 42100 | total loss: 2.05e-01 | train loss: 2.05e-01 |  test error: 2.83e-03
# step = 42200 | total loss: 1.94e-01 | train loss: 1.94e-01 |  test error: 3.24e-03
# step = 42300 | total loss: 1.93e-01 | train loss: 1.93e-01 |  test error: 3.33e-03
# step = 42400 | total loss: 1.94e-01 | train loss: 1.94e-01 |  test error: 3.04e-03
# step = 42500 | total loss: 1.92e-01 | train loss: 1.92e-01 |  test error: 3.19e-03
# step = 42600 | total loss: 1.91e-01 | train loss: 1.91e-01 |  test error: 3.30e-03
# step = 42700 | total loss: 1.91e-01 | train loss: 1.91e-01 |  test error: 3.23e-03
# step = 42800 | total loss: 1.90e-01 | train loss: 1.90e-01 |  test error: 3.12e-03
# step = 42900 | total loss: 1.90e-01 | train loss: 1.90e-01 |  test error: 3.10e-03
# step = 43000 | total loss: 1.89e-01 | train loss: 1.89e-01 |  test error: 3.03e-03
# step = 43100 | total loss: 1.89e-01 | train loss: 1.89e-01 |  test error: 2.94e-03
# step = 43200 | total loss: 1.87e-01 | train loss: 1.87e-01 |  test error: 3.06e-03
# step = 43300 | total loss: 1.87e-01 | train loss: 1.87e-01 |  test error: 3.04e-03
# step = 43400 | total loss: 1.87e-01 | train loss: 1.87e-01 |  test error: 3.33e-03
# step = 43500 | total loss: 1.86e-01 | train loss: 1.86e-01 |  test error: 2.97e-03
# step = 43600 | total loss: 1.86e-01 | train loss: 1.86e-01 |  test error: 2.99e-03
# step = 43700 | total loss: 1.85e-01 | train loss: 1.85e-01 |  test error: 3.01e-03
# step = 43800 | total loss: 1.88e-01 | train loss: 1.88e-01 |  test error: 3.07e-03
# step = 43900 | total loss: 1.84e-01 | train loss: 1.84e-01 |  test error: 3.01e-03
# step = 44000 | total loss: 1.83e-01 | train loss: 1.83e-01 |  test error: 2.88e-03
# step = 44100 | total loss: 1.83e-01 | train loss: 1.83e-01 |  test error: 2.98e-03
# step = 44200 | total loss: 1.82e-01 | train loss: 1.82e-01 |  test error: 2.95e-03
# step = 44300 | total loss: 1.82e-01 | train loss: 1.82e-01 |  test error: 2.98e-03
# step = 44400 | total loss: 1.81e-01 | train loss: 1.81e-01 |  test error: 2.81e-03
# step = 44500 | total loss: 1.81e-01 | train loss: 1.81e-01 |  test error: 2.98e-03
# step = 44600 | total loss: 1.80e-01 | train loss: 1.80e-01 |  test error: 2.98e-03
# step = 44700 | total loss: 1.80e-01 | train loss: 1.80e-01 |  test error: 2.97e-03
# step = 44800 | total loss: 1.79e-01 | train loss: 1.79e-01 |  test error: 2.97e-03
# step = 44900 | total loss: 1.79e-01 | train loss: 1.79e-01 |  test error: 2.98e-03
# step = 45000 | total loss: 1.78e-01 | train loss: 1.78e-01 |  test error: 2.97e-03
# step = 45100 | total loss: 1.78e-01 | train loss: 1.78e-01 |  test error: 3.04e-03
# step = 45200 | total loss: 1.78e-01 | train loss: 1.78e-01 |  test error: 2.98e-03
# step = 45300 | total loss: 1.77e-01 | train loss: 1.77e-01 |  test error: 3.12e-03
# step = 45400 | total loss: 1.77e-01 | train loss: 1.77e-01 |  test error: 2.98e-03
# step = 45500 | total loss: 1.76e-01 | train loss: 1.76e-01 |  test error: 2.96e-03
# step = 45600 | total loss: 1.76e-01 | train loss: 1.76e-01 |  test error: 2.98e-03
# step = 45700 | total loss: 1.75e-01 | train loss: 1.75e-01 |  test error: 2.94e-03
# step = 45800 | total loss: 1.92e-01 | train loss: 1.92e-01 |  test error: 4.77e-03
# step = 45900 | total loss: 1.74e-01 | train loss: 1.74e-01 |  test error: 2.95e-03
# step = 46000 | total loss: 1.76e-01 | train loss: 1.76e-01 |  test error: 2.64e-03
# step = 46100 | total loss: 1.74e-01 | train loss: 1.74e-01 |  test error: 3.00e-03
# step = 46200 | total loss: 1.73e-01 | train loss: 1.73e-01 |  test error: 2.98e-03
# step = 46300 | total loss: 1.73e-01 | train loss: 1.73e-01 |  test error: 2.98e-03
# step = 46400 | total loss: 1.73e-01 | train loss: 1.73e-01 |  test error: 2.92e-03
# step = 46500 | total loss: 1.72e-01 | train loss: 1.72e-01 |  test error: 2.98e-03
# step = 46600 | total loss: 1.71e-01 | train loss: 1.71e-01 |  test error: 3.08e-03
# step = 46700 | total loss: 1.73e-01 | train loss: 1.73e-01 |  test error: 3.11e-03
# step = 46800 | total loss: 1.71e-01 | train loss: 1.71e-01 |  test error: 2.93e-03
# step = 46900 | total loss: 1.70e-01 | train loss: 1.70e-01 |  test error: 2.85e-03
# step = 47000 | total loss: 1.71e-01 | train loss: 1.71e-01 |  test error: 2.69e-03
# step = 47100 | total loss: 1.69e-01 | train loss: 1.69e-01 |  test error: 2.95e-03
# step = 47200 | total loss: 1.70e-01 | train loss: 1.70e-01 |  test error: 2.76e-03
# step = 47300 | total loss: 1.69e-01 | train loss: 1.69e-01 |  test error: 2.93e-03
# step = 47400 | total loss: 1.69e-01 | train loss: 1.69e-01 |  test error: 2.80e-03
# step = 47500 | total loss: 1.68e-01 | train loss: 1.68e-01 |  test error: 2.86e-03
# step = 47600 | total loss: 1.68e-01 | train loss: 1.68e-01 |  test error: 2.72e-03
# step = 47700 | total loss: 1.67e-01 | train loss: 1.67e-01 |  test error: 2.87e-03
# step = 47800 | total loss: 1.67e-01 | train loss: 1.67e-01 |  test error: 2.11e-03
# step = 47900 | total loss: 1.66e-01 | train loss: 1.66e-01 |  test error: 2.84e-03
# step = 48000 | total loss: 1.66e-01 | train loss: 1.66e-01 |  test error: 2.24e-03
# step = 48100 | total loss: 1.66e-01 | train loss: 1.66e-01 |  test error: 2.83e-03
# step = 48200 | total loss: 1.65e-01 | train loss: 1.65e-01 |  test error: 2.86e-03
# step = 48300 | total loss: 1.71e-01 | train loss: 1.71e-01 |  test error: 2.03e-03
# step = 48400 | total loss: 1.65e-01 | train loss: 1.65e-01 |  test error: 2.83e-03
# step = 48500 | total loss: 1.64e-01 | train loss: 1.64e-01 |  test error: 2.80e-03
# step = 48600 | total loss: 1.72e-01 | train loss: 1.72e-01 |  test error: 2.54e-03
# step = 48700 | total loss: 1.63e-01 | train loss: 1.63e-01 |  test error: 2.74e-03
# step = 48800 | total loss: 1.64e-01 | train loss: 1.64e-01 |  test error: 2.64e-03
# step = 48900 | total loss: 1.63e-01 | train loss: 1.63e-01 |  test error: 2.69e-03
# step = 49000 | total loss: 1.62e-01 | train loss: 1.62e-01 |  test error: 2.47e-03
# step = 49100 | total loss: 1.68e-01 | train loss: 1.68e-01 |  test error: 2.28e-03
# step = 49200 | total loss: 1.62e-01 | train loss: 1.62e-01 |  test error: 2.68e-03
# step = 49300 | total loss: 1.61e-01 | train loss: 1.61e-01 |  test error: 2.62e-03
# step = 49400 | total loss: 1.66e-01 | train loss: 1.66e-01 |  test error: 3.21e-03
# step = 49500 | total loss: 1.61e-01 | train loss: 1.61e-01 |  test error: 2.64e-03
# step = 49600 | total loss: 1.62e-01 | train loss: 1.62e-01 |  test error: 2.69e-03
# step = 49700 | total loss: 1.60e-01 | train loss: 1.60e-01 |  test error: 2.59e-03
# step = 49800 | total loss: 1.60e-01 | train loss: 1.60e-01 |  test error: 2.63e-03
# step = 49900 | total loss: 1.61e-01 | train loss: 1.61e-01 |  test error: 2.87e-03
# step = 50000 | total loss: 1.59e-01 | train loss: 1.59e-01 |  test error: 2.54e-03
# step = 50100 | total loss: 1.59e-01 | train loss: 1.59e-01 |  test error: 2.50e-03
# step = 50200 | total loss: 1.59e-01 | train loss: 1.59e-01 |  test error: 3.17e-03
# step = 50300 | total loss: 1.58e-01 | train loss: 1.58e-01 |  test error: 2.50e-03
# step = 50400 | total loss: 1.58e-01 | train loss: 1.58e-01 |  test error: 2.86e-03
# step = 50500 | total loss: 1.57e-01 | train loss: 1.57e-01 |  test error: 2.48e-03
# step = 50600 | total loss: 1.57e-01 | train loss: 1.57e-01 |  test error: 2.79e-03
# step = 50700 | total loss: 1.57e-01 | train loss: 1.57e-01 |  test error: 2.38e-03
# step = 50800 | total loss: 1.56e-01 | train loss: 1.56e-01 |  test error: 2.50e-03
# step = 50900 | total loss: 1.62e-01 | train loss: 1.62e-01 |  test error: 2.86e-03
# step = 51000 | total loss: 1.56e-01 | train loss: 1.56e-01 |  test error: 2.38e-03
# step = 51100 | total loss: 1.56e-01 | train loss: 1.56e-01 |  test error: 1.96e-03
# step = 51200 | total loss: 1.55e-01 | train loss: 1.55e-01 |  test error: 2.45e-03
# step = 51300 | total loss: 1.55e-01 | train loss: 1.55e-01 |  test error: 2.33e-03
# step = 51400 | total loss: 1.55e-01 | train loss: 1.55e-01 |  test error: 3.13e-03
# step = 51500 | total loss: 1.54e-01 | train loss: 1.54e-01 |  test error: 2.31e-03
# step = 51600 | total loss: 1.54e-01 | train loss: 1.54e-01 |  test error: 2.66e-03
# step = 51700 | total loss: 1.53e-01 | train loss: 1.53e-01 |  test error: 2.27e-03
# step = 51800 | total loss: 1.53e-01 | train loss: 1.53e-01 |  test error: 2.23e-03
# step = 51900 | total loss: 1.55e-01 | train loss: 1.55e-01 |  test error: 2.21e-03
# step = 52000 | total loss: 1.53e-01 | train loss: 1.53e-01 |  test error: 2.20e-03
# step = 52100 | total loss: 1.52e-01 | train loss: 1.52e-01 |  test error: 2.31e-03
# step = 52200 | total loss: 1.63e-01 | train loss: 1.63e-01 |  test error: 3.05e-03
# step = 52300 | total loss: 1.52e-01 | train loss: 1.52e-01 |  test error: 2.17e-03
# step = 52400 | total loss: 1.51e-01 | train loss: 1.51e-01 |  test error: 1.97e-03
# step = 52500 | total loss: 1.51e-01 | train loss: 1.51e-01 |  test error: 2.12e-03
# step = 52600 | total loss: 1.51e-01 | train loss: 1.51e-01 |  test error: 1.98e-03
# step = 52700 | total loss: 1.55e-01 | train loss: 1.55e-01 |  test error: 1.80e-03
# step = 52800 | total loss: 1.50e-01 | train loss: 1.50e-01 |  test error: 2.08e-03
# step = 52900 | total loss: 1.50e-01 | train loss: 1.50e-01 |  test error: 2.02e-03
# step = 53000 | total loss: 1.50e-01 | train loss: 1.50e-01 |  test error: 2.47e-03
# step = 53100 | total loss: 1.49e-01 | train loss: 1.49e-01 |  test error: 1.91e-03
# step = 53200 | total loss: 1.50e-01 | train loss: 1.50e-01 |  test error: 1.46e-03
# step = 53300 | total loss: 1.49e-01 | train loss: 1.49e-01 |  test error: 2.01e-03
# step = 53400 | total loss: 1.48e-01 | train loss: 1.48e-01 |  test error: 2.12e-03
# step = 53500 | total loss: 1.48e-01 | train loss: 1.48e-01 |  test error: 2.16e-03
# step = 53600 | total loss: 1.48e-01 | train loss: 1.48e-01 |  test error: 2.02e-03
# step = 53700 | total loss: 1.54e-01 | train loss: 1.54e-01 |  test error: 3.03e-03
# step = 53800 | total loss: 1.47e-01 | train loss: 1.47e-01 |  test error: 1.94e-03
# step = 53900 | total loss: 1.47e-01 | train loss: 1.47e-01 |  test error: 1.91e-03
# step = 54000 | total loss: 1.49e-01 | train loss: 1.49e-01 |  test error: 1.36e-03
# step = 54100 | total loss: 1.46e-01 | train loss: 1.46e-01 |  test error: 1.96e-03
# step = 54200 | total loss: 1.46e-01 | train loss: 1.46e-01 |  test error: 1.88e-03
# step = 54300 | total loss: 1.46e-01 | train loss: 1.46e-01 |  test error: 2.04e-03
# step = 54400 | total loss: 1.45e-01 | train loss: 1.45e-01 |  test error: 1.85e-03
# step = 54500 | total loss: 1.45e-01 | train loss: 1.45e-01 |  test error: 1.82e-03
# step = 54600 | total loss: 1.48e-01 | train loss: 1.48e-01 |  test error: 2.45e-03
# step = 54700 | total loss: 1.45e-01 | train loss: 1.45e-01 |  test error: 1.79e-03
# step = 54800 | total loss: 1.45e-01 | train loss: 1.45e-01 |  test error: 1.72e-03
# step = 54900 | total loss: 1.45e-01 | train loss: 1.45e-01 |  test error: 1.10e-03
# step = 55000 | total loss: 1.46e-01 | train loss: 1.46e-01 |  test error: 2.23e-03
# step = 55100 | total loss: 1.52e-01 | train loss: 1.52e-01 |  test error: 3.15e-03
# step = 55200 | total loss: 1.45e-01 | train loss: 1.45e-01 |  test error: 2.02e-03
# step = 55300 | total loss: 1.43e-01 | train loss: 1.43e-01 |  test error: 1.71e-03
# step = 55400 | total loss: 1.42e-01 | train loss: 1.42e-01 |  test error: 1.72e-03
# step = 55500 | total loss: 1.55e-01 | train loss: 1.55e-01 |  test error: 2.14e-03
# step = 55600 | total loss: 1.42e-01 | train loss: 1.42e-01 |  test error: 1.67e-03
# step = 55700 | total loss: 1.44e-01 | train loss: 1.44e-01 |  test error: 1.40e-03
# step = 55800 | total loss: 1.41e-01 | train loss: 1.41e-01 |  test error: 1.66e-03
# step = 55900 | total loss: 1.42e-01 | train loss: 1.42e-01 |  test error: 1.65e-03
# step = 56000 | total loss: 1.41e-01 | train loss: 1.41e-01 |  test error: 1.65e-03
# step = 56100 | total loss: 1.40e-01 | train loss: 1.40e-01 |  test error: 1.58e-03
# step = 56200 | total loss: 1.41e-01 | train loss: 1.41e-01 |  test error: 1.33e-03
# step = 56300 | total loss: 1.40e-01 | train loss: 1.40e-01 |  test error: 1.57e-03
# step = 56400 | total loss: 1.40e-01 | train loss: 1.40e-01 |  test error: 1.65e-03
# step = 56500 | total loss: 1.39e-01 | train loss: 1.39e-01 |  test error: 1.54e-03
# step = 56600 | total loss: 1.39e-01 | train loss: 1.39e-01 |  test error: 1.08e-03
# step = 56700 | total loss: 1.38e-01 | train loss: 1.38e-01 |  test error: 1.53e-03
# step = 56800 | total loss: 1.38e-01 | train loss: 1.38e-01 |  test error: 1.43e-03
# step = 56900 | total loss: 1.38e-01 | train loss: 1.38e-01 |  test error: 1.56e-03
# step = 57000 | total loss: 1.37e-01 | train loss: 1.37e-01 |  test error: 1.50e-03
# step = 57100 | total loss: 1.46e-01 | train loss: 1.46e-01 |  test error: 2.85e-03
# ...
# step = 81000 | total loss: 5.73e-02 | train loss: 5.73e-02 |  test error: 1.56e-04
# step = 81100 | total loss: 5.72e-02 | train loss: 5.72e-02 |  test error: 2.11e-04
# step = 81200 | total loss: 5.69e-02 | train loss: 5.69e-02 |  test error: 1.62e-04
# step = 81300 | total loss: 5.71e-02 | train loss: 5.71e-02 |  test error: 1.51e-04
# step = 81400 | total loss: 5.65e-02 | train loss: 5.65e-02 |  test error: 1.44e-04
# step = 81500 | total loss: 5.96e-02 | train loss: 5.96e-02 |  test error: 2.58e-04
# step = 81600 | total loss: 5.62e-02 | train loss: 5.62e-02 |  test error: 1.46e-04
# step = 81700 | total loss: 5.60e-02 | train loss: 5.60e-02 |  test error: 1.45e-04
# step = 81800 | total loss: 5.64e-02 | train loss: 5.64e-02 |  test error: 1.79e-04
# step = 81900 | total loss: 5.65e-02 | train loss: 5.65e-02 |  test error: 1.43e-04
# step = 82000 | total loss: 5.74e-02 | train loss: 5.74e-02 |  test error: 4.76e-04
# step = 82100 | total loss: 5.54e-02 | train loss: 5.54e-02 |  test error: 1.40e-04
# step = 82200 | total loss: 5.63e-02 | train loss: 5.63e-02 |  test error: 1.80e-04
# step = 82300 | total loss: 5.81e-02 | train loss: 5.81e-02 |  test error: 7.65e-04
# step = 82400 | total loss: 5.56e-02 | train loss: 5.56e-02 |  test error: 1.47e-04
# step = 82500 | total loss: 5.47e-02 | train loss: 5.47e-02 |  test error: 1.37e-04
# step = 82600 | total loss: 6.03e-02 | train loss: 6.03e-02 |  test error: 3.19e-04
# step = 82700 | total loss: 5.47e-02 | train loss: 5.47e-02 |  test error: 2.29e-04
# step = 82800 | total loss: 6.76e-02 | train loss: 6.76e-02 |  test error: 4.13e-04
# step = 82900 | total loss: 5.38e-02 | train loss: 5.38e-02 |  test error: 1.30e-04
# step = 83000 | total loss: 5.37e-02 | train loss: 5.37e-02 |  test error: 1.35e-04
# step = 83100 | total loss: 5.37e-02 | train loss: 5.37e-02 |  test error: 1.23e-04
# step = 83200 | total loss: 5.33e-02 | train loss: 5.33e-02 |  test error: 1.28e-04
# step = 83300 | total loss: 5.98e-02 | train loss: 5.98e-02 |  test error: 4.20e-04
# step = 83400 | total loss: 5.29e-02 | train loss: 5.29e-02 |  test error: 1.23e-04
# step = 83500 | total loss: 5.28e-02 | train loss: 5.28e-02 |  test error: 1.18e-04
# step = 83600 | total loss: 5.71e-02 | train loss: 5.71e-02 |  test error: 1.94e-04
# step = 83700 | total loss: 5.24e-02 | train loss: 5.24e-02 |  test error: 1.21e-04
# step = 83800 | total loss: 5.25e-02 | train loss: 5.25e-02 |  test error: 1.28e-04
# step = 83900 | total loss: 6.21e-02 | train loss: 6.21e-02 |  test error: 6.15e-04
# step = 84000 | total loss: 5.19e-02 | train loss: 5.19e-02 |  test error: 1.17e-04
# step = 84100 | total loss: 5.17e-02 | train loss: 5.17e-02 |  test error: 1.12e-04
# step = 84200 | total loss: 5.26e-02 | train loss: 5.26e-02 |  test error: 4.21e-04
# step = 84300 | total loss: 5.14e-02 | train loss: 5.14e-02 |  test error: 1.10e-04
# step = 84400 | total loss: 5.51e-02 | train loss: 5.51e-02 |  test error: 7.47e-04
# step = 84500 | total loss: 5.10e-02 | train loss: 5.10e-02 |  test error: 1.14e-04
# step = 84600 | total loss: 5.09e-02 | train loss: 5.09e-02 |  test error: 1.16e-04
# step = 84700 | total loss: 5.06e-02 | train loss: 5.06e-02 |  test error: 1.10e-04
# step = 84800 | total loss: 5.08e-02 | train loss: 5.08e-02 |  test error: 1.78e-04
# step = 84900 | total loss: 5.19e-02 | train loss: 5.19e-02 |  test error: 4.77e-04
# step = 85000 | total loss: 5.29e-02 | train loss: 5.29e-02 |  test error: 2.08e-04
# step = 85100 | total loss: 4.99e-02 | train loss: 4.99e-02 |  test error: 1.06e-04
# step = 85200 | total loss: 4.97e-02 | train loss: 4.97e-02 |  test error: 1.06e-04
# step = 85300 | total loss: 4.95e-02 | train loss: 4.95e-02 |  test error: 1.15e-04
# step = 85400 | total loss: 4.93e-02 | train loss: 4.93e-02 |  test error: 1.06e-04
# step = 85500 | total loss: 5.00e-02 | train loss: 5.00e-02 |  test error: 2.07e-04
# step = 85600 | total loss: 5.64e-02 | train loss: 5.64e-02 |  test error: 1.32e-03
# step = 85700 | total loss: 5.05e-02 | train loss: 5.05e-02 |  test error: 1.21e-04
# step = 85800 | total loss: 4.85e-02 | train loss: 4.85e-02 |  test error: 9.93e-05
# step = 85900 | total loss: 4.83e-02 | train loss: 4.83e-02 |  test error: 1.01e-04
# step = 86000 | total loss: 4.82e-02 | train loss: 4.82e-02 |  test error: 1.01e-04
# step = 86100 | total loss: 4.80e-02 | train loss: 4.80e-02 |  test error: 9.85e-05
# step = 86200 | total loss: 5.43e-02 | train loss: 5.43e-02 |  test error: 4.05e-04
# step = 86300 | total loss: 4.76e-02 | train loss: 4.76e-02 |  test error: 9.34e-05
# step = 86400 | total loss: 4.74e-02 | train loss: 4.74e-02 |  test error: 9.55e-05
# step = 86500 | total loss: 4.72e-02 | train loss: 4.72e-02 |  test error: 9.76e-05
# step = 86600 | total loss: 4.76e-02 | train loss: 4.76e-02 |  test error: 1.14e-04
# step = 86700 | total loss: 4.68e-02 | train loss: 4.68e-02 |  test error: 9.40e-05
# step = 86800 | total loss: 4.66e-02 | train loss: 4.66e-02 |  test error: 9.75e-05
# step = 86900 | total loss: 4.69e-02 | train loss: 4.69e-02 |  test error: 1.71e-04
# step = 87000 | total loss: 4.62e-02 | train loss: 4.62e-02 |  test error: 9.19e-05
# step = 87100 | total loss: 4.61e-02 | train loss: 4.61e-02 |  test error: 9.49e-05
# step = 87200 | total loss: 4.60e-02 | train loss: 4.60e-02 |  test error: 8.59e-05
# step = 87300 | total loss: 4.57e-02 | train loss: 4.57e-02 |  test error: 9.08e-05
# step = 87400 | total loss: 4.55e-02 | train loss: 4.55e-02 |  test error: 9.34e-05
# step = 87500 | total loss: 4.54e-02 | train loss: 4.54e-02 |  test error: 8.62e-05
# step = 87600 | total loss: 4.57e-02 | train loss: 4.57e-02 |  test error: 2.35e-04
# step = 87700 | total loss: 4.51e-02 | train loss: 4.51e-02 |  test error: 8.98e-05
# step = 87800 | total loss: 4.49e-02 | train loss: 4.49e-02 |  test error: 9.21e-05
# step = 87900 | total loss: 4.49e-02 | train loss: 4.49e-02 |  test error: 8.47e-05
# step = 88000 | total loss: 4.46e-02 | train loss: 4.46e-02 |  test error: 8.84e-05
# step = 88100 | total loss: 4.44e-02 | train loss: 4.44e-02 |  test error: 9.37e-05
# step = 88200 | total loss: 4.46e-02 | train loss: 4.46e-02 |  test error: 1.02e-04
# step = 88300 | total loss: 4.41e-02 | train loss: 4.41e-02 |  test error: 8.58e-05
# step = 88400 | total loss: 4.40e-02 | train loss: 4.40e-02 |  test error: 9.31e-05
# step = 88500 | total loss: 4.58e-02 | train loss: 4.58e-02 |  test error: 4.46e-04
# step = 88600 | total loss: 4.37e-02 | train loss: 4.37e-02 |  test error: 8.34e-05
# step = 88700 | total loss: 4.36e-02 | train loss: 4.36e-02 |  test error: 8.01e-05
# step = 88800 | total loss: 4.35e-02 | train loss: 4.35e-02 |  test error: 1.32e-04
# step = 88900 | total loss: 4.39e-02 | train loss: 4.39e-02 |  test error: 9.25e-05
# step = 89000 | total loss: 4.32e-02 | train loss: 4.32e-02 |  test error: 9.15e-05
# step = 89100 | total loss: 4.30e-02 | train loss: 4.30e-02 |  test error: 7.61e-05
# step = 89200 | total loss: 5.67e-02 | train loss: 5.67e-02 |  test error: 4.03e-04
# step = 89300 | total loss: 4.28e-02 | train loss: 4.28e-02 |  test error: 8.14e-05
# step = 89400 | total loss: 4.44e-02 | train loss: 4.44e-02 |  test error: 2.53e-04
# step = 89500 | total loss: 4.25e-02 | train loss: 4.25e-02 |  test error: 7.72e-05
# step = 89600 | total loss: 4.24e-02 | train loss: 4.24e-02 |  test error: 8.02e-05
# step = 89700 | total loss: 4.27e-02 | train loss: 4.27e-02 |  test error: 2.12e-04
# step = 89800 | total loss: 4.21e-02 | train loss: 4.21e-02 |  test error: 7.36e-05
# step = 89900 | total loss: 4.20e-02 | train loss: 4.20e-02 |  test error: 6.69e-05
# step = 90000 | total loss: 4.18e-02 | train loss: 4.18e-02 |  test error: 6.85e-05
# step = 90100 | total loss: 5.24e-02 | train loss: 5.24e-02 |  test error: 3.81e-04
# step = 90200 | total loss: 4.16e-02 | train loss: 4.16e-02 |  test error: 7.25e-05
# step = 90300 | total loss: 4.15e-02 | train loss: 4.15e-02 |  test error: 6.77e-05
# step = 90400 | total loss: 4.13e-02 | train loss: 4.13e-02 |  test error: 6.79e-05
# step = 90500 | total loss: 4.13e-02 | train loss: 4.13e-02 |  test error: 6.22e-05
# step = 90600 | total loss: 4.33e-02 | train loss: 4.33e-02 |  test error: 3.19e-04
# step = 90700 | total loss: 4.10e-02 | train loss: 4.10e-02 |  test error: 6.25e-05
# step = 90800 | total loss: 4.08e-02 | train loss: 4.08e-02 |  test error: 6.33e-05
# step = 90900 | total loss: 4.17e-02 | train loss: 4.17e-02 |  test error: 9.24e-05
# step = 91000 | total loss: 4.09e-02 | train loss: 4.09e-02 |  test error: 1.64e-04
# step = 91100 | total loss: 4.05e-02 | train loss: 4.05e-02 |  test error: 7.01e-05
# step = 91200 | total loss: 4.09e-02 | train loss: 4.09e-02 |  test error: 1.80e-04
# step = 91300 | total loss: 4.05e-02 | train loss: 4.05e-02 |  test error: 6.94e-05
# step = 91400 | total loss: 4.09e-02 | train loss: 4.09e-02 |  test error: 7.04e-05
# step = 91500 | total loss: 4.00e-02 | train loss: 4.00e-02 |  test error: 6.84e-05
# step = 91600 | total loss: 3.99e-02 | train loss: 3.99e-02 |  test error: 9.31e-05
# step = 91700 | total loss: 3.98e-02 | train loss: 3.98e-02 |  test error: 6.51e-05
# step = 91800 | total loss: 3.96e-02 | train loss: 3.96e-02 |  test error: 5.80e-05
# step = 91900 | total loss: 3.95e-02 | train loss: 3.95e-02 |  test error: 5.70e-05
# step = 92000 | total loss: 3.94e-02 | train loss: 3.94e-02 |  test error: 6.61e-05
# step = 92100 | total loss: 3.97e-02 | train loss: 3.97e-02 |  test error: 1.52e-04
# step = 92200 | total loss: 4.11e-02 | train loss: 4.11e-02 |  test error: 3.11e-04
# step = 92300 | total loss: 3.90e-02 | train loss: 3.90e-02 |  test error: 5.69e-05
# step = 92400 | total loss: 3.89e-02 | train loss: 3.89e-02 |  test error: 6.12e-05
# step = 92500 | total loss: 3.88e-02 | train loss: 3.88e-02 |  test error: 5.66e-05
# step = 92600 | total loss: 3.89e-02 | train loss: 3.89e-02 |  test error: 5.92e-05
# step = 92700 | total loss: 3.86e-02 | train loss: 3.86e-02 |  test error: 5.48e-05
# step = 92800 | total loss: 3.85e-02 | train loss: 3.85e-02 |  test error: 7.79e-05
# step = 92900 | total loss: 5.37e-02 | train loss: 5.37e-02 |  test error: 4.01e-04
# step = 93000 | total loss: 3.82e-02 | train loss: 3.82e-02 |  test error: 5.28e-05
# step = 93100 | total loss: 3.82e-02 | train loss: 3.82e-02 |  test error: 5.74e-05
# step = 93200 | total loss: 3.81e-02 | train loss: 3.81e-02 |  test error: 6.42e-05
# step = 93300 | total loss: 3.87e-02 | train loss: 3.87e-02 |  test error: 1.93e-04
# step = 93400 | total loss: 4.20e-02 | train loss: 4.20e-02 |  test error: 1.86e-04
# step = 93500 | total loss: 4.02e-02 | train loss: 4.02e-02 |  test error: 4.85e-04
# step = 93600 | total loss: 3.76e-02 | train loss: 3.76e-02 |  test error: 4.83e-05
# step = 93700 | total loss: 3.75e-02 | train loss: 3.75e-02 |  test error: 5.30e-05
# step = 93800 | total loss: 3.83e-02 | train loss: 3.83e-02 |  test error: 1.26e-04
# step = 93900 | total loss: 3.73e-02 | train loss: 3.73e-02 |  test error: 4.82e-05
# step = 94000 | total loss: 3.72e-02 | train loss: 3.72e-02 |  test error: 5.07e-05
# step = 94100 | total loss: 3.80e-02 | train loss: 3.80e-02 |  test error: 6.79e-05
# step = 94200 | total loss: 3.77e-02 | train loss: 3.77e-02 |  test error: 8.57e-05
# step = 94300 | total loss: 4.22e-02 | train loss: 4.22e-02 |  test error: 7.76e-04
# step = 94400 | total loss: 3.90e-02 | train loss: 3.90e-02 |  test error: 1.75e-04
# step = 94500 | total loss: 4.31e-02 | train loss: 4.31e-02 |  test error: 4.48e-04
# step = 94600 | total loss: 3.65e-02 | train loss: 3.65e-02 |  test error: 4.95e-05
# step = 94700 | total loss: 3.64e-02 | train loss: 3.64e-02 |  test error: 4.90e-05
# step = 94800 | total loss: 3.66e-02 | train loss: 3.66e-02 |  test error: 7.12e-05
# step = 94900 | total loss: 3.80e-02 | train loss: 3.80e-02 |  test error: 1.24e-04
# step = 95000 | total loss: 3.83e-02 | train loss: 3.83e-02 |  test error: 3.82e-04
# step = 95100 | total loss: 3.84e-02 | train loss: 3.84e-02 |  test error: 2.01e-04
# step = 95200 | total loss: 3.59e-02 | train loss: 3.59e-02 |  test error: 4.91e-05
# step = 95300 | total loss: 3.76e-02 | train loss: 3.76e-02 |  test error: 2.01e-04
# step = 95400 | total loss: 3.83e-02 | train loss: 3.83e-02 |  test error: 9.42e-05
# step = 95500 | total loss: 3.64e-02 | train loss: 3.64e-02 |  test error: 1.94e-04
# step = 95600 | total loss: 3.64e-02 | train loss: 3.64e-02 |  test error: 9.29e-05
# step = 95700 | total loss: 3.54e-02 | train loss: 3.54e-02 |  test error: 4.41e-05
# step = 95800 | total loss: 3.60e-02 | train loss: 3.60e-02 |  test error: 5.46e-05
# step = 95900 | total loss: 4.47e-02 | train loss: 4.47e-02 |  test error: 2.60e-04
# step = 96000 | total loss: 3.53e-02 | train loss: 3.53e-02 |  test error: 7.90e-05
# step = 96100 | total loss: 3.61e-02 | train loss: 3.61e-02 |  test error: 1.70e-04
# step = 96200 | total loss: 3.52e-02 | train loss: 3.52e-02 |  test error: 8.78e-05
# step = 96300 | total loss: 3.56e-02 | train loss: 3.56e-02 |  test error: 6.25e-05
# step = 96400 | total loss: 3.48e-02 | train loss: 3.48e-02 |  test error: 4.31e-05
# step = 96500 | total loss: 3.47e-02 | train loss: 3.47e-02 |  test error: 4.19e-05
# step = 96600 | total loss: 3.48e-02 | train loss: 3.48e-02 |  test error: 5.55e-05
# step = 96700 | total loss: 3.52e-02 | train loss: 3.52e-02 |  test error: 1.36e-04
# step = 96800 | total loss: 3.44e-02 | train loss: 3.44e-02 |  test error: 4.99e-05
# step = 96900 | total loss: 3.43e-02 | train loss: 3.43e-02 |  test error: 4.40e-05
# step = 97000 | total loss: 3.42e-02 | train loss: 3.42e-02 |  test error: 4.26e-05
# step = 97100 | total loss: 3.42e-02 | train loss: 3.42e-02 |  test error: 5.61e-05
# step = 97200 | total loss: 3.40e-02 | train loss: 3.40e-02 |  test error: 4.36e-05
# step = 97300 | total loss: 3.41e-02 | train loss: 3.41e-02 |  test error: 4.54e-05
# step = 97400 | total loss: 3.39e-02 | train loss: 3.39e-02 |  test error: 4.40e-05
# step = 97500 | total loss: 3.67e-02 | train loss: 3.67e-02 |  test error: 2.24e-04
# step = 97600 | total loss: 3.59e-02 | train loss: 3.59e-02 |  test error: 1.07e-04
# step = 97700 | total loss: 3.40e-02 | train loss: 3.40e-02 |  test error: 8.15e-05
# step = 97800 | total loss: 3.38e-02 | train loss: 3.38e-02 |  test error: 4.21e-05
# step = 97900 | total loss: 3.61e-02 | train loss: 3.61e-02 |  test error: 3.52e-04
# step = 98000 | total loss: 3.33e-02 | train loss: 3.33e-02 |  test error: 4.28e-05
# step = 98100 | total loss: 3.33e-02 | train loss: 3.33e-02 |  test error: 4.06e-05
# step = 98200 | total loss: 3.35e-02 | train loss: 3.35e-02 |  test error: 4.70e-05
# step = 98300 | total loss: 3.31e-02 | train loss: 3.31e-02 |  test error: 4.25e-05
# step = 98400 | total loss: 3.30e-02 | train loss: 3.30e-02 |  test error: 6.00e-05
# step = 98500 | total loss: 3.29e-02 | train loss: 3.29e-02 |  test error: 4.27e-05
# step = 98600 | total loss: 3.35e-02 | train loss: 3.35e-02 |  test error: 8.62e-05
# step = 98700 | total loss: 4.08e-02 | train loss: 4.08e-02 |  test error: 3.40e-04
# step = 98800 | total loss: 3.27e-02 | train loss: 3.27e-02 |  test error: 7.39e-05
# step = 98900 | total loss: 3.26e-02 | train loss: 3.26e-02 |  test error: 4.58e-05
# step = 99000 | total loss: 3.27e-02 | train loss: 3.27e-02 |  test error: 4.31e-05
# step = 99100 | total loss: 3.25e-02 | train loss: 3.25e-02 |  test error: 6.73e-05
# step = 99200 | total loss: 3.23e-02 | train loss: 3.23e-02 |  test error: 4.18e-05
# step = 99300 | total loss: 3.22e-02 | train loss: 3.22e-02 |  test error: 5.40e-05
# step = 99400 | total loss: 3.28e-02 | train loss: 3.28e-02 |  test error: 6.89e-05
# step = 99500 | total loss: 3.28e-02 | train loss: 3.28e-02 |  test error: 1.19e-04
# step = 99600 | total loss: 3.45e-02 | train loss: 3.45e-02 |  test error: 2.15e-04
# step = 99700 | total loss: 3.20e-02 | train loss: 3.20e-02 |  test error: 3.73e-05
# step = 99800 | total loss: 3.39e-02 | train loss: 3.39e-02 |  test error: 1.22e-04
# step = 99900 | total loss: 3.59e-02 | train loss: 3.59e-02 |  test error: 1.80e-04

# %% [markdown]
# **Training Done**
#
# plot the final architecture

# %%
model2.plot()
plt.show()

# %% [markdown]
# Plot the history of different losses. Note the different phases of the training when the lambda and penalization change.

# %%
# plot loss function
window = 100
average_test = []
average_train = []
for ind in range(len(hist_test_error) - window + 1):
    average_test.append(np.mean(hist_test_error[ind:ind+window]))
    average_train.append(np.mean(hist_train_loss[ind:ind+window]))

epoch = np.linspace(1,steps,steps) 
plt.figure(figsize=(12,6))
plt.semilogy(average_train, linewidth=0.5, label="Train Loss - MSE") 
plt.semilogy(average_test, alpha=0.5, label="Num. VS. Analytical Solution - MSE") 
plt.xlabel("epoch", fontsize=16)
plt.ylabel("loss", fontsize=16)
plt.legend()
plt.xlim([0,steps])
plt.grid()
plt.show()

# %%
average_train_modular = average_train
average_test_modular = average_test
# %store average_train_modular
# %store average_test_modular
# Out:
# Stored 'average_train_modular' (list)
# Stored 'average_test_modular' (list)

# %% [markdown]
# Compare the analytical solution and PINN solution.

# %%
pred_test = model(inputs_test)
plt.plot(inputs_test.detach().numpy(), pred_test.detach().numpy(),'.',label="PINN Solution")
plt.plot(inputs_test.detach().numpy(), Analytical_sol ,'.', alpha=0.5, label="Analytical Solution")
#plt.plot(inputs_test12.detach().numpy(), pred_test12.detach().numpy(),'.',label="PINN Gen. Solution")
plt.xlabel("t", fontsize=14)
plt.ylabel("Solution", fontsize=14)
plt.legend()
plt.xlim([0,2*np.pi])
plt.grid()
plt.show()

# %% [markdown]
# Calculate L2 error of the PINN solution

# %%
PINN_sol = pred_test.detach().numpy() 
print("Error (Euclidean Norm): ",np.linalg.norm(PINN_sol-Analytical_sol))
# Out:
# Error (Euclidean Norm):  0.08348579

# %%
pred_test = model1(inputs_test)
plt.plot(inputs_test.detach().numpy(), pred_test.detach().numpy(),'.',label="PINN Solution")
plt.plot(inputs_test.detach().numpy(), Analytical_sol ,'.', alpha=0.5, label="Analytical Solution")
#plt.plot(inputs_test12.detach().numpy(), pred_test12.detach().numpy(),'.',label="PINN Gen. Solution")
plt.xlabel("x", fontsize=14)
plt.ylabel("Solution", fontsize=14)
plt.legend()
plt.xlim([0,2*np.pi])
plt.grid()
plt.show()

# %%
pred_test = model2(inputs_test)
plt.plot(inputs_test.detach().numpy(), pred_test.detach().numpy(),'.',label="PINN Solution")
plt.plot(inputs_test.detach().numpy(), Analytical_sol ,'.', alpha=0.5, label="Analytical Solution")
#plt.plot(inputs_test12.detach().numpy(), pred_test12.detach().numpy(),'.',label="PINN Gen. Solution")
plt.xlabel("x", fontsize=14)
plt.ylabel("Solution", fontsize=14)
plt.legend()
plt.xlim([0,2*np.pi])
plt.grid()
plt.show()

# %%
pred_test = model3(inputs_test) 
plt.plot(inputs_test.detach().numpy(), pred_test.detach().numpy(),'.',label="PINN Solution")
plt.plot(inputs_test.detach().numpy(), Analytical_sol ,'.', alpha=0.5, label="Analytical Solution")
#plt.plot(inputs_test12.detach().numpy(), pred_test12.detach().numpy(),'.',label="PINN Gen. Solution")
plt.xlabel("x", fontsize=14)
plt.ylabel("Solution", fontsize=14)
plt.legend()
plt.xlim([0,2*np.pi])
plt.grid()
plt.show()

# %% [markdown]
# Print the weights and biases of the final PINN - *full precision*

# %%
torch.set_printoptions(precision=10)
# print the weights and biases
for name, param in model1.named_parameters():
  print(name)
  print(param.data)
# Out:
# in_perm
# tensor([0.])
# out_perm
# tensor([0.])
# linears.0.linear.weight
# tensor([[-1.7029068470],
#         [-1.5325843096],
#         [ 1.8064980507]])
# linears.0.linear.bias
# tensor([ 0.7000871897,  2.5965478420, -1.9533026218])
# linears.1.linear.weight
# tensor([[2.6332454681, 1.9731894732, 1.7731496096]])
# linears.1.linear.bias
# tensor([-0.5425386429])

# %% [markdown]
# remove one link manually

# %%
with torch.no_grad():
    for param in model.parameters():
            param.data = param*(param!=-0.8263503313)
for name, param in model.named_parameters():
  print(name)
  print(param.data)
# Out:
# model1.in_perm
# tensor([0.])
# model1.out_perm
# tensor([0.])
# model1.linears.0.linear.weight
# tensor([[-1.7029068470],
#         [-1.5325843096],
#         [ 1.8064980507]])
# model1.linears.0.linear.bias
# tensor([ 0.7000871897,  2.5965478420, -1.9533026218])
# model1.linears.1.linear.weight
# tensor([[2.6332454681, 1.9731894732, 1.7731496096]])
# model1.linears.1.linear.bias
# tensor([-0.5425386429])
# model2.in_perm
# tensor([0.])
# model2.out_perm
# tensor([0.])
# model2.linears.0.linear.weight
# tensor([[ 1.0270069838],
#         [-1.2941846848],
#         [ 1.2028939724]])
# model2.linears.0.linear.bias
# tensor([ 0.5198077559,  1.0538749695, -3.9421765804])
# model2.linears.1.linear.weight
# tensor([[-1.4578906298, -3.8761703968, -1.4799454212]])
# model2.linears.1.linear.bias
# tensor([-0.5425386429])

# %% [markdown]
# Check the network to see if the connection is removed

# %%
model.plot()
plt.show()

# %% [markdown]
# Plot the solution after removing a connection

# %%
pred_test_new = model(inputs_test)
plt.plot(inputs_test.detach().numpy(), pred_test_new.detach().numpy(),'.',label="PINN Solution")
plt.plot(inputs_test.detach().numpy(), Analytical_sol ,'.', alpha=0.5, label="Analytical Solution")
#plt.plot(inputs_test12.detach().numpy(), pred_test12.detach().numpy(),'.',label="PINN Gen. Solution")
plt.xlabel("x", fontsize=14)
plt.ylabel("Solution", fontsize=14)
plt.legend()
plt.xlim([0,2*np.pi])
plt.grid()
plt.show()

# %% [markdown]
# Remove an additional link

# %%
with torch.no_grad():
    for param in model.parameters():
            param.data = param*(param!=-1.5461428165)
for name, param in model.named_parameters():
  print(name)
  print(param.data)
# Out:
# in_perm
# tensor([0.])
# out_perm
# tensor([0.])
# linears.0.linear.weight
# tensor([[ 0.0000000000],
#         [-0.0000000000],
#         [ 0.0000000000],
#         [-0.0000000000],
#         [ 0.0000000000],
#         [ 0.0000000000],
#         [-0.0000000000],
#         [-0.0000000000],
#         [ 0.5705066323],
#         [-0.5370593071],
#         [ 0.9470548034],
#         [ 0.5947775245],
#         [-0.0000000000],
#         [-0.0000000000],
#         [ 0.0000000000],
#         [ 0.0000000000],
#         [ 0.0000000000],
#         [ 0.0000000000],
#         [ 0.0000000000],
#         [ 0.0000000000],
#         [-0.0000000000]])
# linears.0.linear.bias
# tensor([ 0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#         -0.0000000000,  0.0000000000,  0.0000000000,  0.0000000000,
#         -1.3589568138,  0.7347847819, -0.7477640510, -1.8531508446,
#         -0.0000000000, -0.0000000000,  0.0000000000, -0.0000000000,
#          0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#          0.0000000000])
# linears.1.linear.weight
# tensor([[ 0.0000000000, -0.0000000000,  0.0000000000,  0.0000000000,
#           0.0000000000, -0.0000000000, -0.0000000000,  0.0000000000,
#           0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#          -0.0000000000,  0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000, -0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000],
#         [ 0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#           0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#           0.0000000000, -0.0000000000, -0.0000000000, -0.0000000000,
#           0.0000000000,  0.0000000000,  0.0000000000,  0.0000000000,
#           0.0000000000, -0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000],
#         [ 0.0000000000,  0.0000000000,  0.0000000000,  0.0000000000,
#           0.0000000000,  0.0000000000,  0.0000000000,  0.0000000000,
#           0.0000000000,  0.0000000000,  0.0000000000,  0.0000000000,
#           0.0000000000, -0.0000000000, -0.0000000000,  0.0000000000,
#          -0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#          -0.0000000000],
#         [ 0.0000000000,  0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000,  0.0000000000, -0.0000000000, -0.0000000000,
#          -0.0000000000,  0.0000000000,  0.0000000000, -0.0000000000,
#          -0.0000000000, -0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000, -0.0000000000,  0.0000000000,  0.0000000000,
#          -0.0000000000],
#         [ 0.0000000000, -0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000,  0.0000000000,  0.0000000000,  0.0000000000,
#          -0.0000000000, -0.0000000000, -0.0000000000,  0.0000000000,
#           0.0000000000,  0.0000000000, -0.0000000000, -0.0000000000,
#           0.0000000000, -0.0000000000,  0.0000000000,  0.0000000000,
#           0.0000000000],
#         [ 0.0000000000, -0.0000000000, -0.0000000000, -0.0000000000,
#           0.0000000000, -0.0000000000,  0.0000000000,  0.0000000000,
#          -0.0000000000,  0.0000000000,  0.0000000000, -0.0000000000,
#          -0.0000000000, -0.0000000000, -0.0000000000, -0.0000000000,
#          -0.0000000000,  0.0000000000,  0.0000000000,  0.0000000000,
#          -0.0000000000],
#         [ 0.0000000000, -0.0000000000, -0.0000000000, -0.0000000000,
#           0.0000000000, -0.0000000000, -0.0000000000, -0.0000000000,
#          -0.0000000000, -0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000,  0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000, -0.0000000000,  0.0000000000,  0.0000000000,
#          -0.0000000000],
#         [-0.0000000000, -0.0000000000,  0.0000000000,  0.0000000000,
#           0.0000000000, -0.0000000000, -0.0000000000,  0.0000000000,
#          -0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#           0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#          -0.0000000000,  0.0000000000, -0.0000000000, -0.0000000000,
#          -0.0000000000],
#         [-0.0000000000, -0.0000000000, -0.0000000000, -0.0000000000,
#           0.0000000000,  0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000, -0.0000000000,  0.0000000000,  0.0000000000,
#          -0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#          -0.0000000000, -0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000],
#         [-0.0000000000,  0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000, -0.0000000000, -0.0000000000,  0.0000000000,
#           0.8232162595,  1.6671431065, -0.0000000000,  0.0522790141,
#           0.0000000000, -0.0000000000, -0.0000000000,  0.0000000000,
#          -0.0000000000, -0.0000000000,  0.0000000000,  0.0000000000,
#           0.0000000000],
#         [-0.0000000000,  0.0000000000,  0.0000000000, -0.0000000000,
#          -0.0000000000, -0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000, -0.0000000000, -0.7220783830, -0.0138596017,
#          -0.0000000000, -0.0000000000,  0.0000000000,  0.0000000000,
#           0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#           0.0000000000],
#         [-0.0000000000,  0.0000000000, -0.0000000000, -0.0000000000,
#          -0.0000000000,  0.0000000000,  0.0000000000,  0.0000000000,
#           0.0000000000, -0.0000000000,  0.6750302315,  1.9279900789,
#          -0.0000000000, -0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#           0.0000000000],
#         [-0.0000000000,  0.0000000000, -0.0000000000, -0.0000000000,
#          -0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#          -0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#           0.0000000000,  0.0000000000,  0.0000000000,  0.0000000000,
#           0.0000000000,  0.0000000000, -0.0000000000, -0.0000000000,
#           0.0000000000],
#         [-0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#          -0.0000000000, -0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000,  0.0000000000,  0.0000000000, -0.0000000000,
#          -0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#          -0.0000000000,  0.0000000000,  0.0000000000,  0.0000000000,
#          -0.0000000000],
#         [ 0.0000000000,  0.0000000000, -0.0000000000, -0.0000000000,
#           0.0000000000, -0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000,  0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000, -0.0000000000, -0.0000000000,  0.0000000000,
#          -0.0000000000, -0.0000000000, -0.0000000000, -0.0000000000,
#          -0.0000000000],
#         [-0.0000000000, -0.0000000000, -0.0000000000,  0.0000000000,
#           0.0000000000, -0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#           0.0000000000,  0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000,  0.0000000000,  0.0000000000, -0.0000000000,
#          -0.0000000000],
#         [-0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#          -0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#           0.0000000000, -0.0000000000, -0.0000000000, -0.0000000000,
#          -0.0000000000,  0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#          -0.0000000000],
#         [-0.0000000000, -0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#           0.0000000000,  0.0000000000, -0.0000000000, -0.0000000000,
#          -0.0000000000,  0.0000000000,  0.0000000000,  0.0000000000,
#          -0.0000000000, -0.0000000000, -0.0000000000,  0.0000000000,
#          -0.0000000000],
#         [ 0.0000000000, -0.0000000000, -0.0000000000,  0.0000000000,
#           0.0000000000, -0.0000000000, -0.0000000000, -0.0000000000,
#           0.0000000000, -0.0000000000, -0.0000000000, -0.0000000000,
#          -0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#           0.0000000000, -0.0000000000, -0.0000000000,  0.0000000000,
#           0.0000000000],
#         [ 0.0000000000,  0.0000000000,  0.0000000000,  0.0000000000,
#          -0.0000000000, -0.0000000000,  0.0000000000,  0.0000000000,
#          -0.0000000000, -0.0000000000, -0.0000000000, -0.0000000000,
#          -0.0000000000, -0.0000000000,  0.0000000000,  0.0000000000,
#           0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#          -0.0000000000],
#         [ 0.0000000000,  0.0000000000,  0.0000000000, -0.0000000000,
#           0.0000000000, -0.0000000000, -0.0000000000, -0.0000000000,
#          -0.0000000000, -0.0000000000,  0.0000000000,  0.0000000000,
#          -0.0000000000, -0.0000000000, -0.0000000000,  0.0000000000,
#           0.0000000000,  0.0000000000,  0.0000000000, -0.0000000000,
#          -0.0000000000]])
# linears.1.linear.bias
# tensor([-0.0000000000,  0.0000000000,  0.0000000000, -0.0000000000,
#          0.0000000000,  0.0000000000,  0.0000000000, -0.0000000000,
#          0.0000000000,  0.0356447771,  1.4719792604, -1.0803377628,
#         -0.0000000000, -0.0000000000, -0.0000000000, -0.0000000000,
#          0.0000000000,  0.0000000000, -0.0000000000,  0.0000000000,
#         -0.0000000000])
# linears.2.linear.weight
# tensor([[0.0000000000, -0.0000000000, -0.0000000000, 0.0000000000, -0.0000000000,
#          -0.0000000000, -0.0000000000, 0.0000000000, -0.0000000000, 1.6244239807,
#          -0.0000000000, -0.0000000000, 0.0000000000, 0.0000000000, 0.0000000000,
#          0.0000000000, 0.0000000000, -0.0000000000, 0.0000000000, 0.0000000000,
#          -0.0000000000]])
# linears.2.linear.bias
# tensor([0.7555535436])

# %% [markdown]
# check the new architecture

# %%
model.plot()

# %% [markdown]
# Plot the new solution after removing two connections

# %%
pred_test_new = model(inputs_test)
plt.plot(inputs_test.detach().numpy(), pred_test_new.detach().numpy(),'.',label="PINN Solution")
plt.plot(inputs_test.detach().numpy(), Analytical_sol ,'.', alpha=0.5, label="Analytical Solution")
#plt.plot(inputs_test12.detach().numpy(), pred_test12.detach().numpy(),'.',label="PINN Gen. Solution")
plt.xlabel("x", fontsize=14)
plt.ylabel("Solution", fontsize=14)
plt.legend()
plt.xlim([0,2*np.pi])
plt.grid()
plt.show()
